# %% [markdown]
# ### Import utilities

# %%
import pandas as pd
from coordinates import Transcripts

# %%
data = pd.read_csv("blast_dyn_ribo_merged_candidates.csv")
data = data.drop("Unnamed: 0",axis = 1)

# %%
data
# Out:
#                 query  length sequence  score        expect  \
# 0     ENST00000621052    1275   O00370  140.0  4.000000e-32
# 1     ENST00000549804    1032   B0Y4D6   37.0  3.200000e+00
# 2     ENST00000415801     159   Q96CB5   64.3  2.000000e-10
# 3     ENST00000609590     367   O54689  557.0  0.000000e+00
# 4     ENST00000523176     683   O94929   69.3  2.000000e-10
# ...               ...     ...      ...    ...           ...
# 1318  ENST00000588290     531   Q9NV72   38.9  1.200000e-02
# 1319  ENST00000521197     401   Q5IS58   35.8  2.700000e-01
# 1320  ENST00000641534     464   P04198   71.2  3.000000e-14
# 1321  ENST00000528233     230   Q96NF6   66.6  3.000000e-12
# 1322  ENST00000599924     174   Q8N2A0   59.3  8.000000e-11
#
#                             method     identities      positives        gaps  \
# 0     Compositional matrix adjust.    66/84 (79%)    73/84 (87%)   0/84 (0%)
# 1     Compositional matrix adjust.    26/73 (36%)    39/73 (53%)   4/73 (5%)
# ...

# %%
trans = Transcripts()

# %%
given_transcript_ids = list(data["query"])

# %%
transcript_properties, _ = trans.map_transcript_ids(given_transcript_ids)

# %%
transcript_properties
# Out:
# {'ENST00000621052': {'contig': '14',
#   'start': 19348216,
#   'end': 19384587,
#   'strand': '-',
#   'transcript_name': 'LINC01297-202',
#   'gene_id': 'ENSG00000274827',
#   'biotype': 'lncRNA'},
#  'ENST00000549804': {'contig': '15',
#   'start': 25050632,
#   'end': 25138756,
#   'strand': '+',
#   'transcript_name': 'SNHG14-210',
#   'gene_id': 'ENSG00000224078',
#   'biotype': 'lncRNA'},
#  'ENST00000415801': {'contig': '9',
#   'start': 86948699,
#   'end': 87002033,
#   'strand': '+',
#   'transcript_name': 'GAS1RR-201',
#   'gene_id': 'ENSG00000226237',
#   'biotype': 'lncRNA'},
#  'ENST00000609590': {'contig': '6',
#   'start': 166999405,
#   'end': 167139141,
#   'strand': '+',
#   'transcript_name': '',
#   'gene_id': 'ENSG00000272980',
#   'biotype': 'retained_intron'},
#  'ENST00000523176': {'contig': '5',
#   'start': 149216523,
#   'end': 149276805,
#   'strand': '-',
#   'transcript_name': '',
#   'gene_id': 'ENSG00000253406',
#   'biotype': 'lncRNA'},
# ...
