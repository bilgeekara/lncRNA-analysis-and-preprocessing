# %% [markdown]
# ### Install utilities

# %%
#https://www.ensembl.org/Homo_sapiens/Transcript/Summary?db=core;g=ENSG00000010404;r=X:149503471-149521096;t=ENST00000521702
#https://curatedpython.com/p/pyensembl-is-openvax-pyensembl/index.html#site_related

# %%
# install PyEnsembl
# !pip install PyEnsembl
# Out:
# Collecting PyEnsembl
#   Using cached pyensembl-2.0.0.tar.gz (60 kB)
# Collecting typechecks>=0.0.2
#   Using cached typechecks-0.1.0.tar.gz (3.4 kB)
# Requirement already satisfied: pandas>=0.15 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from PyEnsembl) (1.3.4)
# Collecting datacache>=1.1.4
#   Using cached datacache-1.1.5.tar.gz (13 kB)
# Collecting memoized-property>=1.0.2
#   Using cached memoized-property-1.0.3.tar.gz (5.0 kB)
# Collecting gtfparse>=1.1.0
#   Using cached gtfparse-1.2.1.tar.gz (12 kB)
# Collecting serializable
#   Using cached serializable-0.2.1.tar.gz (8.4 kB)
# Collecting tinytimer
#   Using cached tinytimer-0.0.0.tar.gz (2.1 kB)
# Collecting appdirs>=1.4.0
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting progressbar33>=2.4
#   Using cached progressbar33-2.4.tar.gz (10 kB)
# Requirement already satisfied: requests>=2.5.1 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from datacache>=1.1.4->PyEnsembl) (2.27.1)
# Collecting mock
#   Using cached mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy>=1.7 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from gtfparse>=1.1.0->PyEnsembl) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from pandas>=0.15->PyEnsembl) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from pandas>=0.15->PyEnsembl) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.15->PyEnsembl) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from requests>=2.5.1->datacache>=1.1.4->PyEnsembl) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from requests>=2.5.1->datacache>=1.1.4->PyEnsembl) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from requests>=2.5.1->datacache>=1.1.4->PyEnsembl) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/cyrillemesue/anaconda3/envs/discovererenv/lib/python3.7/site-packages (from requests>=2.5.1->datacache>=1.1.4->PyEnsembl) (2.0.12)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 953 kB/s eta 0:00:01
# Building wheels for collected packages: PyEnsembl, datacache, gtfparse, memoized-property, progressbar33, typechecks, serializable, tinytimer
#   Building wheel for PyEnsembl (setup.py) ... done
#   Created wheel for PyEnsembl: filename=pyensembl-2.0.0-py3-none-any.whl size=56151 sha256=e7a1726110920733ca7741e3188ad601e0049d3f3d472d0824bc720ba80038f8
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/8a/4d/e3/325e443dd546743dfb5d8eec7c20c94940e3cbb4c72c82ec24
#   Building wheel for datacache (setup.py) ... done
#   Created wheel for datacache: filename=datacache-1.1.5-py3-none-any.whl size=16471 sha256=9bbfcd877b12a122c86f0d3fb2e8468f42200a9b4019af964061ef09085f2856
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/83/dd/38/d52c1ed3ad3ec655ea30a429de1cf89fac1009e8cb0365703a
#   Building wheel for gtfparse (setup.py) ... done
#   Created wheel for gtfparse: filename=gtfparse-1.2.1-py3-none-any.whl size=11637 sha256=5fba397f39aa65db5e6e8ec992c40e26917760b86868324038bfa505b5bf5409
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/a9/7a/45/434ba7d04afbfcc5c12195682413f53ecd4580dfd62905a672
#   Building wheel for memoized-property (setup.py) ... done
#   Created wheel for memoized-property: filename=memoized_property-1.0.3-py2.py3-none-any.whl size=4198 sha256=dd4446ce2b44dda352c9dbcf9822b4bca60bcd2fe7e017506d4642a6f75acdf1
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/de/7b/fe/699bb0345131d630549d98185b87309eb5921d460df9f5562d
#   Building wheel for progressbar33 (setup.py) ... done
#   Created wheel for progressbar33: filename=progressbar33-2.4-py3-none-any.whl size=12156 sha256=93c6a2ef3509c4f015a1d29762b1f9a360a5f301ffce78339417489a90557d47
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/70/34/90/051529053958a4c8e6b33b7c2c2a7de679cfb62703da0383d2
#   Building wheel for typechecks (setup.py) ... done
#   Created wheel for typechecks: filename=typechecks-0.1.0-py3-none-any.whl size=2770 sha256=65c6e8ef8aa50a372f96499970ede736c0a8adddbab145e448fa7cfac9579410
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/26/a1/81/12d88e4ce3aa69eb239909d47a85c66ad562f02afe5a6d8579
#   Building wheel for serializable (setup.py) ... done
#   Created wheel for serializable: filename=serializable-0.2.1-py3-none-any.whl size=8959 sha256=ee8edb1bf1632b66587daf05ea0b9d81555fe9a874333319fdb6ea917d012618
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/3c/98/e3/2db23d6c49379663dc3b1fc5cbf1baf92a3b75f2ff9a63f6a7
#   Building wheel for tinytimer (setup.py) ... done
#   Created wheel for tinytimer: filename=tinytimer-0.0.0-py3-none-any.whl size=1891 sha256=604860e195d461b609e6b368759e976614149f42a151818e544f1d7abd55e6bb
#   Stored in directory: /home/cyrillemesue/.cache/pip/wheels/ef/7f/5a/edcc3bbfc3ef527291fef1440c9fec7fbdf2a156c6cd4d831c
# Successfully built PyEnsembl datacache gtfparse memoized-property progressbar33 typechecks serializable tinytimer
# Installing collected packages: typechecks, simplejson, progressbar33, mock, appdirs, tinytimer, serializable, memoized-property, gtfparse, datacache, PyEnsembl
# Successfully installed PyEnsembl-2.0.0 appdirs-1.4.4 datacache-1.1.5 gtfparse-1.2.1 memoized-property-1.0.3 mock-4.0.3 progressbar33-2.4 serializable-0.2.1 simplejson-3.17.6 tinytimer-0.0.0 typechecks-0.1.0

# %%
# download the human reference data
# !pyensembl install --release 106 --species homo_sapiens
# Out:
# 2022-08-02 22:58:57,256 - pyensembl.shell - INFO - Running 'install' for EnsemblRelease(release=106, species='homo_sapiens')
# 2022-08-02 22:58:58,402 - pyensembl.sequence_data - INFO - Loaded sequence dictionary from /home/cyrillemesue/.cache/pyensembl/GRCh38/ensembl106/Homo_sapiens.GRCh38.cdna.all.fa.gz.pickle
# 2022-08-02 22:58:58,883 - pyensembl.sequence_data - INFO - Loaded sequence dictionary from /home/cyrillemesue/.cache/pyensembl/GRCh38/ensembl106/Homo_sapiens.GRCh38.ncrna.fa.gz.pickle
# 2022-08-02 22:58:59,117 - pyensembl.sequence_data - INFO - Loaded sequence dictionary from /home/cyrillemesue/.cache/pyensembl/GRCh38/ensembl106/Homo_sapiens.GRCh38.pep.all.fa.gz.pickle

# %% [markdown]
# ### Import Utilities

# %%
from pyensembl import EnsemblRelease

# %% [markdown]
# ### Load Database

# %%
# EnsemblRelease object enables you to access the local database for various information
data = EnsemblRelease(release=106)

# %%
# Construct a Transcript object for given Ensembl transcript ID (e.g. "ENST00000369985")
obj = data.transcript_by_id(transcript_id = "ENST00000369985")
obj
# Out:
# Transcript(transcript_id='ENST00000369985', transcript_name='MYO6-203', gene_id='ENSG00000196586', biotype='protein_coding', contig='6', start=75749239, end=75919537, strand='+', genome='GRCh38')

# %%
# get coordinates
chromosome = obj.contig
start = obj.start
end = obj.end
strand = obj.strand
name = obj.transcript_name
coordinates = f"Chromosome {chromosome}{strand}: {start}:{end}"
coordinates
# Out:
# 'Chromosome 6+: 75749239:75919537'

# %%
# get all transcript ids from database
transcripts = data.transcripts() # get all transcripts for all ids in the database
transcript_ids = []
for transcript in transcripts:
    transcript_ids.append(transcript.transcript_id)

# %%
# this function maps a list of transcript ids to genomic coordinates
def map_transcript_ids(transcript_ids):
    """
    map a list of transcipt ids to their genomic coordinates
    return (raw_coordinates, arranged_coordinates)
        raw coordinates contain all the transcript entities: name, start, end, contig, strand, etc
        arranged_coordinates coordinates contain the chromosome number, strand, start and end positions 
        as such:'Chromosome 6+: 75749239:75919537' 
    """
    
    raw_coordinates = {}
    arranged_coordinates = {}
    
    # load the ensembl release data
    data = EnsemblRelease(release=106)
    
    def extract_info(Transcript_object):
        """
        extract the essential coordinate info from a given transcript object and returns
        """
        
        extract = {}
        
        extract["contig"] = Transcript_object.contig # chromosome type
        extract["start"] = Transcript_object.start
        extract["end"] = Transcript_object.end
        extract["strand"] = Transcript_object.strand # forward strand(+) reverse strand (-)
        extract["transcript_name"] = Transcript_object.name
        extract["gene_id"] = Transcript_object.gene_id
        extract["biotype"] = Transcript_object.biotype # coding or non-coding
        
        return extract

    for transcript_id in transcript_ids:
        # create a transcript object for the given transcript id
        try:
            Transcript_object = data.transcript_by_id(transcript_id = transcript_id)
        except:
            continue
        
        # extract coordinates from transcript object
        extract = extract_info(Transcript_object)
        
        # record raw coordinates
        raw_coordinates[transcript_id] = extract
        
        # arrange coordinates into a single string 
        coordinates = f'Chromosome {extract["contig"]}{extract["strand"]}: {extract["start"]}:{extract["end"]}'
        
        # record arranged coordinates
        arranged_coordinates[transcript_id] = coordinates
    return raw_coordinates, arranged_coordinates

# %%
mapped_transcripts = map_transcript_ids(transcript_ids)

# %%
mapped_transcripts[0]
# Out:
# {'ENST00000000233': {'contig': '7',
#   'start': 127588411,
#   'end': 127591700,
#   'strand': '+',
#   'transcript_name': 'ARF5-201',
#   'gene_id': 'ENSG00000004059',
#   'biotype': 'protein_coding'},
#  'ENST00000000412': {'contig': '12',
#   'start': 8940361,
#   'end': 8949645,
#   'strand': '-',
#   'transcript_name': 'M6PR-201',
#   'gene_id': 'ENSG00000003056',
#   'biotype': 'protein_coding'},
#  'ENST00000000442': {'contig': '11',
#   'start': 64305524,
#   'end': 64316743,
#   'strand': '+',
#   'transcript_name': 'ESRRA-201',
#   'gene_id': 'ENSG00000173153',
#   'biotype': 'protein_coding'},
#  'ENST00000001008': {'contig': '12',
#   'start': 2794970,
#   'end': 2805423,
#   'strand': '+',
#   'transcript_name': 'FKBP4-201',
#   'gene_id': 'ENSG00000004478',
#   'biotype': 'protein_coding'},
#  'ENST00000001146': {'contig': '2',
#   'start': 72129238,
#   'end': 72147862,
#   'strand': '-',
#   'transcript_name': 'CYP26B1-201',
#   'gene_id': 'ENSG00000003137',
#   'biotype': 'protein_coding'},
#  'ENST00000002125': {'contig': '2',
#   'start': 37231658,
#   'end': 37249160,
#   'strand': '+',
#   'transcript_name': 'NDUFAF7-201',
#   'gene_id': 'ENSG00000003509',
#   'biotype': 'protein_coding'},
#  'ENST00000002165': {'contig': '6',
#   'start': 143494812,
#   'end': 143511720,
#   'strand': '-',
#   'transcript_name': 'FUCA2-201',
#   'gene_id': 'ENSG00000001036',
#   'biotype': 'protein_coding'},
#  'ENST00000002501': {'contig': '16',
#   'start': 90004871,
#   'end': 90019456,
#   'strand': '-',
#   'transcript_name': 'DBNDD1-201',
#   'gene_id': 'ENSG00000003249',
#   'biotype': 'protein_coding'},
#  'ENST00000002596': {'contig': '4',
#   'start': 11393150,
#   'end': 11428894,
#   'strand': '-',
#   'transcript_name': 'HS3ST1-201',
#   'gene_id': 'ENSG00000002587',
#   'biotype': 'protein_coding'},
#  'ENST00000002829': {'contig': '3',
#   'start': 50155324,
#   'end': 50189075,
#   'strand': '+',
#   'transcript_name': 'SEMA3F-201',
#   'gene_id': 'ENSG00000001617',
#   'biotype': 'protein_coding'},
#  'ENST00000003084': {'contig': '7',
#   'start': 117480025,
#   'end': 117668665,
#   'strand': '+',
#   'transcript_name': 'CFTR-201',
#   'gene_id': 'ENSG00000001626',
#   'biotype': 'protein_coding'},
#  'ENST00000003100': {'contig': '7',
#   'start': 92112153,
#   'end': 92134477,
#   'strand': '-',
#   'transcript_name': 'CYP51A1-201',
#   'gene_id': 'ENSG00000001630',
#   'biotype': 'protein_coding'},
#  'ENST00000003302': {'contig': '11',
#   'start': 113797874,
#   'end': 113875570,
#   'strand': '-',
#   'transcript_name': 'USP28-201',
#   'gene_id': 'ENSG00000048028',
#   'biotype': 'protein_coding'},
#  'ENST00000003583': {'contig': '1',
#   'start': 24357005,
#   'end': 24413725,
#   'strand': '-',
#   'transcript_name': 'STPG1-201',
#   'gene_id': 'ENSG00000001460',
#   'biotype': 'protein_coding'},
#  'ENST00000003912': {'contig': '1',
#   'start': 24415803,
#   'end': 24472976,
#   'strand': '+',
#   'transcript_name': 'NIPAL3-201',
#   'gene_id': 'ENSG00000001461',
#   'biotype': 'protein_coding'},
#  'ENST00000004103': {'contig': '7',
#   'start': 150800769,
#   'end': 150805118,
#   'strand': '+',
#   'transcript_name': 'TMEM176A-201',
#   'gene_id': 'ENSG00000002933',
#   'biotype': 'protein_coding'},
#  'ENST00000004531': {'contig': '8',
#   'start': 17538777,
#   'end': 17570561,
#   'strand': '+',
#   'transcript_name': 'SLC7A2-201',
#   'gene_id': 'ENSG00000003989',
#   'biotype': 'protein_coding'},
#  'ENST00000004982': {'contig': '19',
#   'start': 35754566,
#   'end': 35757029,
#   'strand': '-',
#   'transcript_name': 'HSPB6-201',
#   'gene_id': 'ENSG00000004776',
#   'biotype': 'protein_coding'},
#  'ENST00000005082': {'contig': '11',
#   'start': 3358994,
#   'end': 3379116,
#   'strand': '-',
#   'transcript_name': 'ZNF195-201',
#   'gene_id': 'ENSG00000005801',
#   'biotype': 'protein_coding'},
#  'ENST00000005178': {'contig': '7',
#   'start': 95583499,
#   'end': 95596516,
#   'strand': '-',
#   'transcript_name': 'PDK4-201',
#   'gene_id': 'ENSG00000004799',
#   'biotype': 'protein_coding'},
#  'ENST00000005180': {'contig': '7',
#   'start': 75769538,
#   'end': 75772211,
#   'strand': '-',
#   'transcript_name': 'CCL26-201',
#   'gene_id': 'ENSG00000006606',
#   'biotype': 'protein_coding'},
#  'ENST00000005226': {'contig': '11',
#   'start': 17493900,
#   'end': 17544416,
#   'strand': '-',
#   'transcript_name': 'USH1C-201',
#   'gene_id': 'ENSG00000006611',
#   'biotype': 'protein_coding'},
#  'ENST00000005257': {'contig': '7',
#   'start': 39623572,
#   'end': 39708120,
#   'strand': '+',
#   'transcript_name': 'RALA-201',
#   'gene_id': 'ENSG00000006451',
#   'biotype': 'protein_coding'},
#  'ENST00000005259': {'contig': '7',
#   'start': 107580246,
#   'end': 107620478,
#   'strand': '+',
#   'transcript_name': 'BCAP29-201',
#   'gene_id': 'ENSG00000075790',
#   'biotype': 'protein_coding'},
#  'ENST00000005260': {'contig': '7',
#   'start': 98291650,
#   'end': 98401090,
#   'strand': '-',
#   'transcript_name': 'BAIAP2L1-201',
#   'gene_id': 'ENSG00000006453',
#   'biotype': 'protein_coding'},
#  'ENST00000005284': {'contig': '16',
#   'start': 24256335,
#   'end': 24362412,
#   'strand': '+',
#   'transcript_name': 'CACNG3-201',
#   'gene_id': 'ENSG00000006116',
#   'biotype': 'protein_coding'},
#  'ENST00000005286': {'contig': '11',
#   'start': 60924481,
#   'end': 60937159,
#   'strand': '+',
#   'transcript_name': 'TMEM132A-201',
#   'gene_id': 'ENSG00000006118',
#   'biotype': 'protein_coding'},
#  'ENST00000005340': {'contig': '17',
#   'start': 7225342,
#   'end': 7234517,
#   'strand': '-',
#   'transcript_name': 'DVL2-201',
#   'gene_id': 'ENSG00000004975',
#   'biotype': 'protein_coding'},
#  'ENST00000005374': {'contig': '7',
#   'start': 30496623,
#   'end': 30504841,
#   'strand': '-',
#   'transcript_name': 'GGCT-201',
#   'gene_id': 'ENSG00000006625',
#   'biotype': 'protein_coding'},
#  'ENST00000005386': {'contig': '12',
#   'start': 47661249,
#   'end': 47706030,
#   'strand': '-',
#   'transcript_name': 'RPAP3-201',
#   'gene_id': 'ENSG00000005175',
#   'biotype': 'protein_coding'},
#  'ENST00000005558': {'contig': '7',
#   'start': 112423144,
#   'end': 112475527,
#   'strand': '+',
#   'transcript_name': 'IFRD1-201',
#   'gene_id': 'ENSG00000006652',
#   'biotype': 'protein_coding'},
#  'ENST00000005756': {'contig': '2',
#   'start': 158101876,
#   'end': 158136154,
#   'strand': '+',
#   'transcript_name': 'UPP2-201',
#   'gene_id': 'ENSG00000007001',
#   'biotype': 'protein_coding'},
#  'ENST00000005995': {'contig': '16',
#   'start': 2817237,
#   'end': 2821719,
#   'strand': '+',
#   'transcript_name': 'PRSS21-201',
#   'gene_id': 'ENSG00000007038',
#   'biotype': 'protein_coding'},
#  'ENST00000006015': {'contig': '7',
#   'start': 27181157,
#   'end': 27185232,
#   'strand': '-',
#   'transcript_name': 'HOXA11-201',
#   'gene_id': 'ENSG00000005073',
#   'biotype': 'protein_coding'},
#  'ENST00000006053': {'contig': '16',
#   'start': 57372490,
#   'end': 57385044,
#   'strand': '+',
#   'transcript_name': 'CX3CL1-201',
#   'gene_id': 'ENSG00000006210',
#   'biotype': 'protein_coding'},
#  'ENST00000006251': {'contig': '22',
#   'start': 44677057,
#   'end': 44737680,
#   'strand': '+',
#   'transcript_name': 'PRR5-201',
#   'gene_id': 'ENSG00000186654',
#   'biotype': 'protein_coding'},
#  'ENST00000006275': {'contig': '19',
#   'start': 45162928,
#   'end': 45178237,
#   'strand': '-',
#   'transcript_name': 'TRAPPC6A-201',
#   'gene_id': 'ENSG00000007255',
#   'biotype': 'protein_coding'},
#  'ENST00000006658': {'contig': '17',
#   'start': 50547174,
#   'end': 50555852,
#   'strand': '+',
#   'transcript_name': 'SPATA20-201',
#   'gene_id': 'ENSG00000006282',
#   'biotype': 'protein_coding'},
#  'ENST00000006724': {'contig': '19',
#   'start': 41673307,
#   'end': 41688367,
#   'strand': '-',
#   'transcript_name': 'CEACAM7-201',
#   'gene_id': 'ENSG00000007306',
#   'biotype': 'protein_coding'},
#  'ENST00000006750': {'contig': '17',
#   'start': 63928740,
#   'end': 63932331,
#   'strand': '-',
#   'transcript_name': 'CD79B-201',
#   'gene_id': 'ENSG00000007312',
#   'biotype': 'protein_coding'},
#  'ENST00000006777': {'contig': '7',
#   'start': 75879034,
#   'end': 75888926,
#   'strand': '+',
#   'transcript_name': 'RHBDD2-201',
#   'gene_id': 'ENSG00000005486',
#   'biotype': 'protein_coding'},
#  'ENST00000007264': {'contig': '16',
#   'start': 784974,
#   'end': 788381,
#   'strand': '-',
#   'transcript_name': 'RPUSD1-201',
#   'gene_id': 'ENSG00000007376',
#   'biotype': 'protein_coding'},
#  'ENST00000007390': {'contig': '16',
#   'start': 1349240,
#   'end': 1351878,
#   'strand': '-',
#   'transcript_name': 'TSR3-201',
#   'gene_id': 'ENSG00000007520',
#   'biotype': 'protein_coding'},
#  'ENST00000007414': {'contig': '17',
#   'start': 47807372,
#   'end': 47821794,
#   'strand': '-',
#   'transcript_name': 'OSBPL7-201',
#   'gene_id': 'ENSG00000006025',
#   'biotype': 'protein_coding'},
#  'ENST00000007510': {'contig': '19',
#   'start': 35775564,
#   'end': 35788822,
#   'strand': '+',
#   'transcript_name': 'ARHGAP33-201',
#   'gene_id': 'ENSG00000004777',
#   'biotype': 'protein_coding'},
#  'ENST00000007516': {'contig': '16',
#   'start': 23581014,
#   'end': 23596316,
#   'strand': '-',
#   'transcript_name': 'NDUFAB1-201',
#   'gene_id': 'ENSG00000004779',
#   'biotype': 'protein_coding'},
#  'ENST00000007699': {'contig': '17',
#   'start': 7288263,
#   'end': 7294639,
#   'strand': '-',
#   'transcript_name': 'YBX2-201',
#   'gene_id': 'ENSG00000006047',
#   'biotype': 'protein_coding'},
#  'ENST00000007708': {'contig': '17',
#   'start': 50094737,
#   'end': 50111058,
#   'strand': '+',
#   'transcript_name': 'PDK2-201',
#   'gene_id': 'ENSG00000005882',
#   'biotype': 'protein_coding'},
#  'ENST00000007722': {'contig': '17',
#   'start': 50056440,
#   'end': 50089729,
#   'strand': '+',
#   'transcript_name': 'ITGA3-201',
#   'gene_id': 'ENSG00000005884',
#   'biotype': 'protein_coding'},
#  'ENST00000007735': {'contig': '17',
#   'start': 41346092,
#   'end': 41350828,
#   'strand': '-',
#   'transcript_name': 'KRT33A-201',
#   'gene_id': 'ENSG00000006059',
#   'biotype': 'protein_coding'},
#  'ENST00000007969': {'contig': '12',
#   'start': 6904733,
#   'end': 6914229,
#   'strand': '+',
#   'transcript_name': 'LRRC23-201',
#   'gene_id': 'ENSG00000010626',
#   'biotype': 'protein_coding'},
#  'ENST00000008180': {'contig': '16',
#   'start': 3065631,
#   'end': 3069819,
#   'strand': '+',
#   'transcript_name': 'IL32-201',
#   'gene_id': 'ENSG00000008517',
#   'biotype': 'protein_coding'},
#  'ENST00000008391': {'contig': '6',
#   'start': 50713526,
#   'end': 50773033,
#   'strand': '+',
#   'transcript_name': 'TFAP2D-201',
#   'gene_id': 'ENSG00000008197',
#   'biotype': 'protein_coding'},
#  'ENST00000008440': {'contig': '1',
#   'start': 231338256,
#   'end': 231352521,
#   'strand': '+',
#   'transcript_name': 'SPRTN-201',
#   'gene_id': 'ENSG00000010072',
#   'biotype': 'protein_coding'},
#  'ENST00000008527': {'contig': '12',
#   'start': 106991364,
#   'end': 107093549,
#   'strand': '-',
#   'transcript_name': 'CRY1-201',
#   'gene_id': 'ENSG00000008405',
#   'biotype': 'protein_coding'},
#  'ENST00000008876': {'contig': '22',
#   'start': 50603133,
#   'end': 50613981,
#   'strand': '+',
#   'transcript_name': 'MAPK8IP2-201',
#   'gene_id': 'ENSG00000008735',
#   'biotype': 'retained_intron'},
#  'ENST00000008938': {'contig': '19',
#   'start': 46019153,
#   'end': 46023053,
#   'strand': '-',
#   'transcript_name': 'PGLYRP1-201',
#   'gene_id': 'ENSG00000008438',
#   'biotype': 'protein_coding'},
#  'ENST00000009041': {'contig': '7',
#   'start': 38178245,
#   'end': 38230669,
#   'strand': '+',
#   'transcript_name': 'STARD3NL-201',
#   'gene_id': 'ENSG00000010270',
#   'biotype': 'protein_coding'},
#  'ENST00000009105': {'contig': '1',
#   'start': 209583717,
#   'end': 209613938,
#   'strand': '+',
#   'transcript_name': 'CAMK1G-201',
#   'gene_id': 'ENSG00000008118',
#   'biotype': 'protein_coding'},
#  'ENST00000009180': {'contig': '12',
#   'start': 6200400,
#   'end': 6238266,
#   'strand': '+',
#   'transcript_name': 'CD9-201',
#   'gene_id': 'ENSG00000010278',
#   'biotype': 'protein_coding'},
#  'ENST00000009530': {'contig': '5',
#   'start': 150401639,
#   'end': 150412910,
#   'strand': '-',
#   'transcript_name': 'CD74-201',
#   'gene_id': 'ENSG00000019582',
#   'biotype': 'protein_coding'},
#  'ENST00000009589': {'contig': '8',
#   'start': 56073054,
#   'end': 56074506,
#   'strand': '-',
#   'transcript_name': 'RPS20-201',
#   'gene_id': 'ENSG00000008988',
#   'biotype': 'protein_coding'},
#  'ENST00000010132': {'contig': '12',
#   'start': 4590320,
#   'end': 4613888,
#   'strand': '+',
#   'transcript_name': 'DYRK4-201',
#   'gene_id': 'ENSG00000010219',
#   'biotype': 'protein_coding'},
#  'ENST00000010299': {'contig': '1',
#   'start': 27726057,
#   'end': 27760581,
#   'strand': '+',
#   'transcript_name': 'FAM76A-201',
#   'gene_id': 'ENSG00000009780',
#   'biotype': 'protein_coding'},
#  'ENST00000010404': {'contig': '12',
#   'start': 16347142,
#   'end': 16364409,
#   'strand': '+',
#   'transcript_name': 'MGST1-201',
#   'gene_id': 'ENSG00000008394',
#   'biotype': 'protein_coding'},
#  'ENST00000011292': {'contig': '7',
#   'start': 130380494,
#   'end': 130388108,
#   'strand': '+',
#   'transcript_name': 'CPA1-201',
#   'gene_id': 'ENSG00000091704',
#   'biotype': 'protein_coding'},
#  'ENST00000011473': {'contig': '7',
#   'start': 106090505,
#   'end': 106112576,
#   'strand': '-',
#   'transcript_name': 'SYPL1-201',
#   'gene_id': 'ENSG00000008282',
#   'biotype': 'protein_coding'},
#  'ENST00000011619': {'contig': '6',
#   'start': 13621498,
#   'end': 13711835,
#   'strand': '-',
#   'transcript_name': 'RANBP9-201',
#   'gene_id': 'ENSG00000010017',
#   'biotype': 'protein_coding'},
#  'ENST00000011653': {'contig': '12',
#   'start': 6789528,
#   'end': 6820799,
#   'strand': '+',
#   'transcript_name': 'CD4-201',
#   'gene_id': 'ENSG00000010610',
#   'biotype': 'protein_coding'},
#  'ENST00000011684': {'contig': '12',
#   'start': 6310436,
#   'end': 6328505,
#   'strand': '+',
#   'transcript_name': 'PLEKHG6-201',
#   'gene_id': 'ENSG00000008323',
#   'biotype': 'protein_coding'},
#  'ENST00000011691': {'contig': '3',
#   'start': 42590860,
#   'end': 42596934,
#   'strand': '+',
#   'transcript_name': 'SS18L2-201',
#   'gene_id': 'ENSG00000008324',
#   'biotype': 'protein_coding'},
#  'ENST00000011700': {'contig': '1',
#   'start': 12277121,
#   'end': 12510361,
#   'strand': '+',
#   'transcript_name': 'VPS13D-201',
#   'gene_id': 'ENSG00000048707',
#   'biotype': 'protein_coding'},
#  'ENST00000011898': {'contig': '12',
#   'start': 3077379,
#   'end': 3286559,
#   'strand': '+',
#   'transcript_name': 'TSPAN9-201',
#   'gene_id': 'ENSG00000011105',
#   'biotype': 'protein_coding'},
#  'ENST00000011989': {'contig': '19',
#   'start': 15878300,
#   'end': 15898057,
#   'strand': '-',
#   'transcript_name': 'CYP4F2-201',
#   'gene_id': 'ENSG00000186115',
#   'biotype': 'protein_coding'},
#  'ENST00000012049': {'contig': '19',
#   'start': 45692666,
#   'end': 45703987,
#   'strand': '+',
#   'transcript_name': 'QPCTL-201',
#   'gene_id': 'ENSG00000011478',
#   'biotype': 'protein_coding'},
#  'ENST00000012134': {'contig': '6',
#   'start': 142751469,
#   'end': 142945031,
#   'strand': '-',
#   'transcript_name': 'HIVEP2-201',
#   'gene_id': 'ENSG00000010818',
#   'biotype': 'protein_coding'},
#  'ENST00000012443': {'contig': '19',
#   'start': 46347087,
#   'end': 46390975,
#   'strand': '+',
#   'transcript_name': 'PPP5C-201',
#   'gene_id': 'ENSG00000011485',
#   'biotype': 'protein_coding'},
#  'ENST00000013034': {'contig': '17',
#   'start': 51153665,
#   'end': 51161898,
#   'strand': '+',
#   'transcript_name': 'NME1-201',
#   'gene_id': 'ENSG00000239672',
#   'biotype': 'protein_coding'},
#  'ENST00000013070': {'contig': '14',
#   'start': 93207256,
#   'end': 93229215,
#   'strand': '+',
#   'transcript_name': 'UBR7-201',
#   'gene_id': 'ENSG00000012963',
#   'biotype': 'protein_coding'},
#  'ENST00000013125': {'contig': '14',
#   'start': 50418525,
#   'end': 50532609,
#   'strand': '-',
#   'transcript_name': 'MAP4K5-201',
#   'gene_id': 'ENSG00000012983',
#   'biotype': 'protein_coding'},
#  'ENST00000013222': {'contig': '7',
#   'start': 30752135,
#   'end': 30757602,
#   'strand': '+',
#   'transcript_name': 'INMT-201',
#   'gene_id': 'ENSG00000241644',
#   'biotype': 'protein_coding'},
#  'ENST00000013807': {'contig': '19',
#   'start': 45413434,
#   'end': 45423566,
#   'strand': '-',
#   'transcript_name': 'ERCC1-201',
#   'gene_id': 'ENSG00000012061',
#   'biotype': 'protein_coding'},
#  'ENST00000013894': {'contig': '3',
#   'start': 43690951,
#   'end': 43714956,
#   'strand': '+',
#   'transcript_name': 'ABHD5-201',
#   'gene_id': 'ENSG00000011198',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000014914': {'contig': '12',
#   'start': 12891562,
#   'end': 12917937,
#   'strand': '+',
#   'transcript_name': 'GPRC5A-201',
#   'gene_id': 'ENSG00000013588',
#   'biotype': 'protein_coding'},
#  'ENST00000014930': {'contig': '12',
#   'start': 12974870,
#   'end': 13000265,
#   'strand': '-',
#   'transcript_name': 'HEBP1-201',
#   'gene_id': 'ENSG00000013583',
#   'biotype': 'protein_coding'},
#  'ENST00000014935': {'contig': 'X',
#   'start': 154401758,
#   'end': 154410039,
#   'strand': '-',
#   'transcript_name': 'DNASE1L1-201',
#   'gene_id': 'ENSG00000013563',
#   'biotype': 'protein_coding'},
#  'ENST00000016171': {'contig': '10',
#   'start': 99710868,
#   'end': 99732127,
#   'strand': '-',
#   'transcript_name': 'COX15-201',
#   'gene_id': 'ENSG00000014919',
#   'biotype': 'protein_coding'},
#  'ENST00000016913': {'contig': '11',
#   'start': 60492778,
#   'end': 60507430,
#   'strand': '+',
#   'transcript_name': 'MS4A12-201',
#   'gene_id': 'ENSG00000071203',
#   'biotype': 'protein_coding'},
#  'ENST00000016946': {'contig': '2',
#   'start': 109794305,
#   'end': 109857705,
#   'strand': '+',
#   'transcript_name': 'RGPD5-201',
#   'gene_id': 'ENSG00000015568',
#   'biotype': 'protein_coding'},
#  'ENST00000017003': {'contig': '17',
#   'start': 50346126,
#   'end': 50361185,
#   'strand': '+',
#   'transcript_name': 'XYLT2-201',
#   'gene_id': 'ENSG00000015532',
#   'biotype': 'protein_coding'},
#  'ENST00000019019': {'contig': 'X',
#   'start': 48476161,
#   'end': 48486299,
#   'strand': '+',
#   'transcript_name': 'FTSJ1-201',
#   'gene_id': 'ENSG00000068438',
#   'biotype': 'protein_coding'},
#  'ENST00000019103': {'contig': '2',
#   'start': 119439843,
#   'end': 119524483,
#   'strand': '-',
#   'transcript_name': 'SCTR-201',
#   'gene_id': 'ENSG00000080293',
#   'biotype': 'protein_coding'},
#  'ENST00000019317': {'contig': '18',
#   'start': 9475009,
#   'end': 9538114,
#   'strand': '+',
#   'transcript_name': 'RALBP1-201',
#   'gene_id': 'ENSG00000017797',
#   'biotype': 'protein_coding'},
#  'ENST00000020673': {'contig': '10',
#   'start': 102402619,
#   'end': 102418785,
#   'strand': '-',
#   'transcript_name': 'PSD-201',
#   'gene_id': 'ENSG00000059915',
#   'biotype': 'protein_coding'},
#  'ENST00000020926': {'contig': '11',
#   'start': 45240302,
#   'end': 45286341,
#   'strand': '-',
#   'transcript_name': 'SYT13-201',
#   'gene_id': 'ENSG00000019505',
#   'biotype': 'protein_coding'},
#  'ENST00000020945': {'contig': '8',
#   'start': 48917598,
#   'end': 48921429,
#   'strand': '-',
#   'transcript_name': 'SNAI2-201',
#   'gene_id': 'ENSG00000019549',
#   'biotype': 'protein_coding'},
#  'ENST00000022615': {'contig': '8',
#   'start': 42391880,
#   'end': 42405937,
#   'strand': '+',
#   'transcript_name': 'VDAC3-201',
#   'gene_id': 'ENSG00000078668',
#   'biotype': 'protein_coding'},
#  'ENST00000023064': {'contig': '19',
#   'start': 32830511,
#   'end': 32869767,
#   'strand': '-',
#   'transcript_name': 'SLC7A9-201',
#   'gene_id': 'ENSG00000021488',
#   'biotype': 'protein_coding'},
#  'ENST00000023897': {'contig': '5',
#   'start': 161847191,
#   'end': 161897666,
#   'strand': '+',
#   'transcript_name': 'GABRA1-201',
#   'gene_id': 'ENSG00000022355',
#   'biotype': 'protein_coding'},
#  'ENST00000023939': {'contig': '20',
#   'start': 56468585,
#   'end': 56518886,
#   'strand': '+',
#   'transcript_name': 'RTF2-201',
#   'gene_id': 'ENSG00000022277',
#   'biotype': 'protein_coding'},
#  'ENST00000024061': {'contig': '8',
#   'start': 141210601,
#   'end': 141228574,
#   'strand': '-',
#   'transcript_name': 'SLC45A4-201',
#   'gene_id': 'ENSG00000022567',
#   'biotype': 'protein_coding'},
#  'ENST00000025008': {'contig': '8',
#   'start': 52622458,
#   'end': 52714435,
#   'strand': '-',
#   'transcript_name': 'RB1CC1-201',
#   'gene_id': 'ENSG00000023287',
#   'biotype': 'protein_coding'},
#  'ENST00000025301': {'contig': '13',
#   'start': 42272152,
#   'end': 42323261,
#   'strand': '+',
#   'transcript_name': 'AKAP11-201',
#   'gene_id': 'ENSG00000023516',
#   'biotype': 'protein_coding'},
#  'ENST00000025399': {'contig': '12',
#   'start': 15882394,
#   'end': 15903014,
#   'strand': '+',
#   'transcript_name': 'STRAP-201',
#   'gene_id': 'ENSG00000023734',
#   'biotype': 'protein_coding'},
#  'ENST00000026218': {'contig': '16',
#   'start': 570018,
#   'end': 584109,
#   'strand': '+',
#   'transcript_name': 'PIGQ-201',
#   'gene_id': 'ENSG00000007541',
#   'biotype': 'protein_coding'},
#  'ENST00000027335': {'contig': '8',
#   'start': 94127162,
#   'end': 94208555,
#   'strand': '-',
#   'transcript_name': 'CDH17-201',
#   'gene_id': 'ENSG00000079112',
#   'biotype': 'protein_coding'},
#  'ENST00000028008': {'contig': '6',
#   'start': 166929545,
#   'end': 166956584,
#   'strand': '-',
#   'transcript_name': 'RNASET2-201',
#   'gene_id': 'ENSG00000026297',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000029410': {'contig': '5',
#   'start': 177600132,
#   'end': 177610330,
#   'strand': '+',
#   'transcript_name': 'B4GALT7-201',
#   'gene_id': 'ENSG00000027847',
#   'biotype': 'protein_coding'},
#  'ENST00000031146': {'contig': '14',
#   'start': 69398692,
#   'end': 69462381,
#   'strand': '+',
#   'transcript_name': 'SLC39A9-201',
#   'gene_id': 'ENSG00000029364',
#   'biotype': 'protein_coding'},
#  'ENST00000033079': {'contig': '5',
#   'start': 137937960,
#   'end': 138033031,
#   'strand': '-',
#   'transcript_name': 'FAM13B-201',
#   'gene_id': 'ENSG00000031003',
#   'biotype': 'protein_coding'},
#  'ENST00000034275': {'contig': '19',
#   'start': 5917352,
#   'end': 5978086,
#   'strand': '-',
#   'transcript_name': 'RANBP3-201',
#   'gene_id': 'ENSG00000031823',
#   'biotype': 'protein_coding'},
#  'ENST00000035307': {'contig': '7',
#   'start': 151232483,
#   'end': 151238822,
#   'strand': '+',
#   'transcript_name': 'CHPF2-201',
#   'gene_id': 'ENSG00000033100',
#   'biotype': 'protein_coding'},
#  'ENST00000037243': {'contig': '16',
#   'start': 75566379,
#   'end': 75577881,
#   'strand': '+',
#   'transcript_name': 'GABARAPL2-201',
#   'gene_id': 'ENSG00000034713',
#   'biotype': 'protein_coding'},
#  'ENST00000037502': {'contig': '1',
#   'start': 171635417,
#   'end': 171652688,
#   'strand': '-',
#   'transcript_name': 'MYOC-201',
#   'gene_id': 'ENSG00000034971',
#   'biotype': 'protein_coding'},
#  'ENST00000037869': {'contig': '2',
#   'start': 70295975,
#   'end': 70302090,
#   'strand': '-',
#   'transcript_name': 'FAM136A-201',
#   'gene_id': 'ENSG00000035141',
#   'biotype': 'protein_coding'},
#  'ENST00000038176': {'contig': '8',
#   'start': 58583508,
#   'end': 58659853,
#   'strand': '-',
#   'transcript_name': 'NSMAF-201',
#   'gene_id': 'ENSG00000035681',
#   'biotype': 'protein_coding'},
#  'ENST00000039007': {'contig': 'X',
#   'start': 38352604,
#   'end': 38421446,
#   'strand': '+',
#   'transcript_name': 'OTC-201',
#   'gene_id': 'ENSG00000036473',
#   'biotype': 'protein_coding'},
#  'ENST00000039989': {'contig': '11',
#   'start': 43358920,
#   'end': 43494931,
#   'strand': '+',
#   'transcript_name': 'TTC17-201',
#   'gene_id': 'ENSG00000052841',
#   'biotype': 'protein_coding'},
#  'ENST00000040584': {'contig': '12',
#   'start': 54008985,
#   'end': 54012769,
#   'strand': '+',
#   'transcript_name': 'HOXC8-201',
#   'gene_id': 'ENSG00000037965',
#   'biotype': 'protein_coding'},
#  'ENST00000040663': {'contig': '19',
#   'start': 13764522,
#   'end': 13774282,
#   'strand': '+',
#   'transcript_name': 'MRI1-201',
#   'gene_id': 'ENSG00000037757',
#   'biotype': 'protein_coding'},
#  'ENST00000040738': {'contig': '4',
#   'start': 13568738,
#   'end': 13627725,
#   'strand': '-',
#   'transcript_name': 'BOD1L1-201',
#   'gene_id': 'ENSG00000038219',
#   'biotype': 'protein_coding'},
#  'ENST00000040877': {'contig': '1',
#   'start': 234391313,
#   'end': 234479179,
#   'strand': '-',
#   'transcript_name': 'TARBP1-201',
#   'gene_id': 'ENSG00000059588',
#   'biotype': 'protein_coding'},
#  'ENST00000042381': {'contig': '16',
#   'start': 67528829,
#   'end': 67546786,
#   'strand': '+',
#   'transcript_name': 'RIPOR1-201',
#   'gene_id': 'ENSG00000039523',
#   'biotype': 'protein_coding'},
#  'ENST00000042931': {'contig': '19',
#   'start': 12752593,
#   'end': 12758455,
#   'strand': '+',
#   'transcript_name': 'BEST2-201',
#   'gene_id': 'ENSG00000039987',
#   'biotype': 'protein_coding'},
#  'ENST00000043402': {'contig': '22',
#   'start': 20241415,
#   'end': 20268318,
#   'strand': '-',
#   'transcript_name': 'RTN4R-201',
#   'gene_id': 'ENSG00000040608',
#   'biotype': 'protein_coding'},
#  'ENST00000044462': {'contig': '15',
#   'start': 78540444,
#   'end': 78552417,
#   'strand': '+',
#   'transcript_name': 'PSMA4-201',
#   'gene_id': 'ENSG00000041357',
#   'biotype': 'protein_coding'},
#  'ENST00000045083': {'contig': '20',
#   'start': 50586112,
#   'end': 50636889,
#   'strand': '-',
#   'transcript_name': 'RIPOR3-201',
#   'gene_id': 'ENSG00000042062',
#   'biotype': 'protein_coding'},
#  'ENST00000045347': {'contig': '14',
#   'start': 88385819,
#   'end': 88438455,
#   'strand': '+',
#   'transcript_name': 'SPATA7-201',
#   'gene_id': 'ENSG00000042317',
#   'biotype': 'protein_coding'},
#  'ENST00000046087': {'contig': '7',
#   'start': 49937441,
#   'end': 50093246,
#   'strand': '-',
#   'transcript_name': 'ZPBP-201',
#   'gene_id': 'ENSG00000042813',
#   'biotype': 'protein_coding'},
#  'ENST00000046640': {'contig': '17',
#   'start': 3636760,
#   'end': 3663103,
#   'strand': '+',
#   'transcript_name': 'CTNS-201',
#   'gene_id': 'ENSG00000040531',
#   'biotype': 'protein_coding'},
#  'ENST00000046794': {'contig': '5',
#   'start': 170246233,
#   'end': 170297777,
#   'strand': '-',
#   'transcript_name': 'LCP2-201',
#   'gene_id': 'ENSG00000043462',
#   'biotype': 'protein_coding'},
#  'ENST00000052569': {'contig': '6',
#   'start': 117560269,
#   'end': 117602528,
#   'strand': '-',
#   'transcript_name': 'GOPC-201',
#   'gene_id': 'ENSG00000047932',
#   'biotype': 'protein_coding'},
#  'ENST00000052754': {'contig': '12',
#   'start': 91140484,
#   'end': 91182817,
#   'strand': '-',
#   'transcript_name': 'DCN-201',
#   'gene_id': 'ENSG00000011465',
#   'biotype': 'protein_coding'},
#  'ENST00000053243': {'contig': '16',
#   'start': 11965210,
#   'end': 11968068,
#   'strand': '+',
#   'transcript_name': 'TNFRSF17-201',
#   'gene_id': 'ENSG00000048462',
#   'biotype': 'protein_coding'},
#  'ENST00000053468': {'contig': '6',
#   'start': 42206807,
#   'end': 42217861,
#   'strand': '-',
#   'transcript_name': 'MRPS10-201',
#   'gene_id': 'ENSG00000048544',
#   'biotype': 'protein_coding'},
#  'ENST00000053867': {'contig': '17',
#   'start': 44345302,
#   'end': 44353106,
#   'strand': '+',
#   'transcript_name': 'GRN-201',
#   'gene_id': 'ENSG00000030582',
#   'biotype': 'protein_coding'},
#  'ENST00000054650': {'contig': '1',
#   'start': 6624868,
#   'end': 6633562,
#   'strand': '+',
#   'transcript_name': 'THAP3-201',
#   'gene_id': 'ENSG00000041988',
#   'biotype': 'protein_coding'},
#  'ENST00000054666': {'contig': '1',
#   'start': 7771296,
#   'end': 7781432,
#   'strand': '+',
#   'transcript_name': 'VAMP3-201',
#   'gene_id': 'ENSG00000049245',
#   'biotype': 'protein_coding'},
#  'ENST00000054668': {'contig': '1',
#   'start': 7847766,
#   'end': 7853431,
#   'strand': '-',
#   'transcript_name': 'UTS2-201',
#   'gene_id': 'ENSG00000049247',
#   'biotype': 'protein_coding'},
#  'ENST00000054950': {'contig': '11',
#   'start': 32091074,
#   'end': 32105722,
#   'strand': '+',
#   'transcript_name': 'RCN1-201',
#   'gene_id': 'ENSG00000049449',
#   'biotype': 'protein_coding'},
#  'ENST00000055077': {'contig': '7',
#   'start': 74231502,
#   'end': 74254399,
#   'strand': '-',
#   'transcript_name': 'RFC2-201',
#   'gene_id': 'ENSG00000049541',
#   'biotype': 'protein_coding'},
#  'ENST00000055335': {'contig': 'X',
#   'start': 49269793,
#   'end': 49288090,
#   'strand': '+',
#   'transcript_name': 'PPP1R3F-201',
#   'gene_id': 'ENSG00000049769',
#   'biotype': 'protein_coding'},
#  'ENST00000055682': {'contig': 'X',
#   'start': 74732856,
#   'end': 74925452,
#   'strand': '-',
#   'transcript_name': 'NEXMIF-201',
#   'gene_id': 'ENSG00000050030',
#   'biotype': 'protein_coding'},
#  'ENST00000056217': {'contig': '7',
#   'start': 144355402,
#   'end': 144380632,
#   'strand': '+',
#   'transcript_name': 'ARHGEF5-201',
#   'gene_id': 'ENSG00000050327',
#   'biotype': 'protein_coding'},
#  'ENST00000056233': {'contig': '7',
#   'start': 26152198,
#   'end': 26187137,
#   'strand': '+',
#   'transcript_name': 'NFE2L3-201',
#   'gene_id': 'ENSG00000050344',
#   'biotype': 'protein_coding'},
#  'ENST00000057513': {'contig': '4',
#   'start': 121131408,
#   'end': 121164321,
#   'strand': '-',
#   'transcript_name': 'TNIP3-201',
#   'gene_id': 'ENSG00000050730',
#   'biotype': 'protein_coding'},
#  'ENST00000060969': {'contig': '1',
#   'start': 114769479,
#   'end': 114780685,
#   'strand': '-',
#   'transcript_name': 'SIKE1-201',
#   'gene_id': 'ENSG00000052723',
#   'biotype': 'protein_coding'},
#  'ENST00000061240': {'contig': '4',
#   'start': 165873237,
#   'end': 166104457,
#   'strand': '+',
#   'transcript_name': 'TLL1-201',
#   'gene_id': 'ENSG00000038295',
#   'biotype': 'protein_coding'},
#  'ENST00000064571': {'contig': '20',
#   'start': 55997357,
#   'end': 56005519,
#   'strand': '-',
#   'transcript_name': 'CBLN4-201',
#   'gene_id': 'ENSG00000054803',
#   'biotype': 'protein_coding'},
#  'ENST00000064724': {'contig': '3',
#   'start': 170418868,
#   'end': 170434691,
#   'strand': '+',
#   'transcript_name': 'CLDN11-201',
#   'gene_id': 'ENSG00000013297',
#   'biotype': 'protein_coding'},
#  'ENST00000064778': {'contig': '11',
#   'start': 73400487,
#   'end': 73598189,
#   'strand': '-',
#   'transcript_name': 'FAM168A-201',
#   'gene_id': 'ENSG00000054965',
#   'biotype': 'protein_coding'},
#  'ENST00000064780': {'contig': '11',
#   'start': 73376399,
#   'end': 73397474,
#   'strand': '+',
#   'transcript_name': 'RELT-201',
#   'gene_id': 'ENSG00000054967',
#   'biotype': 'protein_coding'},
#  'ENST00000066544': {'contig': '17',
#   'start': 47117703,
#   'end': 47189295,
#   'strand': '-',
#   'transcript_name': 'CDC27-201',
#   'gene_id': 'ENSG00000004897',
#   'biotype': 'protein_coding'},
#  'ENST00000070846': {'contig': '12',
#   'start': 32790755,
#   'end': 32896777,
#   'strand': '-',
#   'transcript_name': 'PKP2-201',
#   'gene_id': 'ENSG00000057294',
#   'biotype': 'protein_coding'},
#  'ENST00000072516': {'contig': '3',
#   'start': 190514051,
#   'end': 190651519,
#   'strand': '+',
#   'transcript_name': 'IL1RAP-201',
#   'gene_id': 'ENSG00000196083',
#   'biotype': 'protein_coding'},
#  'ENST00000072644': {'contig': '1',
#   'start': 53851733,
#   'end': 53889797,
#   'strand': '-',
#   'transcript_name': 'YIPF1-201',
#   'gene_id': 'ENSG00000058799',
#   'biotype': 'protein_coding'},
#  'ENST00000072869': {'contig': '7',
#   'start': 140672945,
#   'end': 140695110,
#   'strand': '+',
#   'transcript_name': 'ADCK2-201',
#   'gene_id': 'ENSG00000133597',
#   'biotype': 'protein_coding'},
#  'ENST00000074304': {'contig': '2',
#   'start': 98444858,
#   'end': 98591033,
#   'strand': '+',
#   'transcript_name': 'INPP4A-201',
#   'gene_id': 'ENSG00000040933',
#   'biotype': 'protein_coding'},
#  'ENST00000075120': {'contig': '12',
#   'start': 7919230,
#   'end': 7936187,
#   'strand': '-',
#   'transcript_name': 'SLC2A3-201',
#   'gene_id': 'ENSG00000059804',
#   'biotype': 'protein_coding'},
#  'ENST00000075322': {'contig': '8',
#   'start': 119557086,
#   'end': 119638839,
#   'strand': '-',
#   'transcript_name': 'ENPP2-201',
#   'gene_id': 'ENSG00000136960',
#   'biotype': 'protein_coding'},
#  'ENST00000075430': {'contig': '18',
#   'start': 79679846,
#   'end': 79754503,
#   'strand': '+',
#   'transcript_name': 'CTDP1-201',
#   'gene_id': 'ENSG00000060069',
#   'biotype': 'protein_coding'},
#  'ENST00000075503': {'contig': '12',
#   'start': 10618923,
#   'end': 10674052,
#   'strand': '-',
#   'transcript_name': 'STYK1-201',
#   'gene_id': 'ENSG00000060140',
#   'biotype': 'protein_coding'},
#  'ENST00000078429': {'contig': '19',
#   'start': 3094362,
#   'end': 3123999,
#   'strand': '+',
#   'transcript_name': 'GNA11-201',
#   'gene_id': 'ENSG00000088256',
#   'biotype': 'protein_coding'},
#  'ENST00000078445': {'contig': '19',
#   'start': 4153631,
#   'end': 4173054,
#   'strand': '+',
#   'transcript_name': 'CREB3L3-201',
#   'gene_id': 'ENSG00000060566',
#   'biotype': 'protein_coding'},
#  'ENST00000078527': {'contig': '1',
#   'start': 26788928,
#   'end': 26798268,
#   'strand': '+',
#   'transcript_name': 'PIGV-201',
#   'gene_id': 'ENSG00000060642',
#   'biotype': 'protein_coding'},
#  'ENST00000080059': {'contig': '12',
#   'start': 47782722,
#   'end': 47819903,
#   'strand': '-',
#   'transcript_name': 'HDAC7-201',
#   'gene_id': 'ENSG00000061273',
#   'biotype': 'protein_coding'},
#  'ENST00000081029': {'contig': '12',
#   'start': 27710832,
#   'end': 27756295,
#   'strand': '+',
#   'transcript_name': 'MRPS35-201',
#   'gene_id': 'ENSG00000061794',
#   'biotype': 'protein_coding'},
#  'ENST00000082468': {'contig': '6',
#   'start': 26402308,
#   'end': 26415204,
#   'strand': '+',
#   'transcript_name': 'BTN3A1-201',
#   'gene_id': 'ENSG00000026950',
#   'biotype': 'retained_intron'},
#  'ENST00000083182': {'contig': '17',
#   'start': 60443158,
#   'end': 60526242,
#   'strand': '-',
#   'transcript_name': 'APPBP2-201',
#   'gene_id': 'ENSG00000062725',
#   'biotype': 'protein_coding'},
#  'ENST00000084795': {'contig': '19',
#   'start': 48615331,
#   'end': 48617884,
#   'strand': '-',
#   'transcript_name': 'RPL18-201',
#   'gene_id': 'ENSG00000063177',
#   'biotype': 'protein_coding'},
#  'ENST00000084798': {'contig': '19',
#   'start': 48637946,
#   'end': 48646187,
#   'strand': '-',
#   'transcript_name': 'CA11-201',
#   'gene_id': 'ENSG00000063180',
#   'biotype': 'protein_coding'},
#  'ENST00000085068': {'contig': '19',
#   'start': 55452989,
#   'end': 55461645,
#   'strand': '-',
#   'transcript_name': 'ISOC2-201',
#   'gene_id': 'ENSG00000063241',
#   'biotype': 'protein_coding'},
#  'ENST00000085079': {'contig': '19',
#   'start': 55675245,
#   'end': 55695766,
#   'strand': '+',
#   'transcript_name': 'EPN1-201',
#   'gene_id': 'ENSG00000063245',
#   'biotype': 'protein_coding'},
#  'ENST00000085219': {'contig': '19',
#   'start': 35329187,
#   'end': 35347361,
#   'strand': '+',
#   'transcript_name': 'CD22-201',
#   'gene_id': 'ENSG00000012124',
#   'biotype': 'protein_coding'},
#  'ENST00000086933': {'contig': '22',
#   'start': 19146993,
#   'end': 19150292,
#   'strand': '-',
#   'transcript_name': 'GSC2-201',
#   'gene_id': 'ENSG00000063515',
#   'biotype': 'protein_coding'},
#  'ENST00000155093': {'contig': 'Y',
#   'start': 2935381,
#   'end': 2982506,
#   'strand': '+',
#   'transcript_name': 'ZFY-201',
#   'gene_id': 'ENSG00000067646',
#   'biotype': 'protein_coding'},
#  'ENST00000155674': {'contig': '22',
#   'start': 17137511,
#   'end': 17165287,
#   'strand': '-',
#   'transcript_name': 'HDHD5-201',
#   'gene_id': 'ENSG00000069998',
#   'biotype': 'protein_coding'},
#  'ENST00000155840': {'contig': '11',
#   'start': 2445008,
#   'end': 2849105,
#   'strand': '+',
#   'transcript_name': 'KCNQ1-201',
#   'gene_id': 'ENSG00000053918',
#   'biotype': 'protein_coding'},
#  'ENST00000155926': {'contig': '2',
#   'start': 12716936,
#   'end': 12742734,
#   'strand': '+',
#   'transcript_name': 'TRIB2-201',
#   'gene_id': 'ENSG00000071575',
#   'biotype': 'protein_coding'},
#  'ENST00000156084': {'contig': 'X',
#   'start': 48922211,
#   'end': 48957631,
#   'strand': '-',
#   'transcript_name': 'OTUD5-201',
#   'gene_id': 'ENSG00000068308',
#   'biotype': 'protein_coding'},
#  'ENST00000156109': {'contig': 'X',
#   'start': 49113407,
#   'end': 49123735,
#   'strand': '-',
#   'transcript_name': 'GPKOW-201',
#   'gene_id': 'ENSG00000068394',
#   'biotype': 'protein_coding'},
#  'ENST00000156471': {'contig': '15',
#   'start': 34851782,
#   'end': 34969742,
#   'strand': '-',
#   'transcript_name': 'AQR-201',
#   'gene_id': 'ENSG00000021776',
#   'biotype': 'protein_coding'},
#  'ENST00000156476': {'contig': '19',
#   'start': 51056206,
#   'end': 51065110,
#   'strand': '-',
#   'transcript_name': 'KLK13-201',
#   'gene_id': 'ENSG00000167759',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000156499': {'contig': '19',
#   'start': 51077495,
#   'end': 51084245,
#   'strand': '-',
#   'transcript_name': 'KLK14-201',
#   'gene_id': 'ENSG00000129437',
#   'biotype': 'protein_coding'},
#  'ENST00000156626': {'contig': '17',
#   'start': 76624763,
#   'end': 76643757,
#   'strand': '-',
#   'transcript_name': 'ST6GALNAC1-201',
#   'gene_id': 'ENSG00000070526',
#   'biotype': 'protein_coding'},
#  'ENST00000156825': {'contig': '19',
#   'start': 1573596,
#   'end': 1592801,
#   'strand': '-',
#   'transcript_name': 'MBD3-201',
#   'gene_id': 'ENSG00000071655',
#   'biotype': 'protein_coding'},
#  'ENST00000157600': {'contig': '3',
#   'start': 8501823,
#   'end': 8574668,
#   'strand': '+',
#   'transcript_name': 'LMCD1-201',
#   'gene_id': 'ENSG00000071282',
#   'biotype': 'protein_coding'},
#  'ENST00000157812': {'contig': '19',
#   'start': 39971165,
#   'end': 39981764,
#   'strand': '+',
#   'transcript_name': 'PSMC4-201',
#   'gene_id': 'ENSG00000013275',
#   'biotype': 'protein_coding'},
#  'ENST00000158009': {'contig': '17',
#   'start': 35121615,
#   'end': 35130732,
#   'strand': '+',
#   'transcript_name': 'FNDC8-201',
#   'gene_id': 'ENSG00000073598',
#   'biotype': 'protein_coding'},
#  'ENST00000158166': {'contig': '17',
#   'start': 3865157,
#   'end': 3893044,
#   'strand': '-',
#   'transcript_name': 'CAMKK1-201',
#   'gene_id': 'ENSG00000004660',
#   'biotype': 'protein_coding'},
#  'ENST00000158526': {'contig': 'X',
#   'start': 154444459,
#   'end': 154450099,
#   'strand': '+',
#   'transcript_name': 'FAM50A-201',
#   'gene_id': 'ENSG00000071859',
#   'biotype': 'protein_coding'},
#  'ENST00000158762': {'contig': '17',
#   'start': 7336529,
#   'end': 7351477,
#   'strand': '+',
#   'transcript_name': 'ACAP1-201',
#   'gene_id': 'ENSG00000072818',
#   'biotype': 'protein_coding'},
#  'ENST00000158771': {'contig': '17',
#   'start': 5471254,
#   'end': 5486178,
#   'strand': '-',
#   'transcript_name': 'DERL2-201',
#   'gene_id': 'ENSG00000072849',
#   'biotype': 'protein_coding'},
#  'ENST00000159060': {'contig': '6',
#   'start': 155395368,
#   'end': 155455839,
#   'strand': '-',
#   'transcript_name': 'NOX3-201',
#   'gene_id': 'ENSG00000074771',
#   'biotype': 'protein_coding'},
#  'ENST00000159087': {'contig': '19',
#   'start': 17323223,
#   'end': 17334855,
#   'strand': '-',
#   'transcript_name': 'ANO8-201',
#   'gene_id': 'ENSG00000074855',
#   'biotype': 'protein_coding'},
#  'ENST00000159111': {'contig': '19',
#   'start': 4969113,
#   'end': 5153598,
#   'strand': '+',
#   'transcript_name': 'KDM4B-201',
#   'gene_id': 'ENSG00000127663',
#   'biotype': 'protein_coding'},
#  'ENST00000159647': {'contig': '22',
#   'start': 50170731,
#   'end': 50180292,
#   'strand': '+',
#   'transcript_name': 'PANX2-201',
#   'gene_id': 'ENSG00000073150',
#   'biotype': 'protein_coding'},
#  'ENST00000160262': {'contig': '19',
#   'start': 10333776,
#   'end': 10339624,
#   'strand': '-',
#   'transcript_name': 'ICAM3-201',
#   'gene_id': 'ENSG00000076662',
#   'biotype': 'protein_coding'},
#  'ENST00000160298': {'contig': '19',
#   'start': 7595863,
#   'end': 7618304,
#   'strand': '+',
#   'transcript_name': 'CAMSAP3-201',
#   'gene_id': 'ENSG00000076826',
#   'biotype': 'protein_coding'},
#  'ENST00000160373': {'contig': '7',
#   'start': 117710651,
#   'end': 117873441,
#   'strand': '-',
#   'transcript_name': 'CTTNBP2-201',
#   'gene_id': 'ENSG00000077063',
#   'biotype': 'protein_coding'},
#  'ENST00000160382': {'contig': '7',
#   'start': 100643097,
#   'end': 100656448,
#   'strand': '-',
#   'transcript_name': 'ACTL6B-201',
#   'gene_id': 'ENSG00000077080',
#   'biotype': 'protein_coding'},
#  'ENST00000160713': {'contig': '8',
#   'start': 138250924,
#   'end': 138425515,
#   'strand': '-',
#   'transcript_name': 'FAM135B-201',
#   'gene_id': 'ENSG00000147724',
#   'biotype': 'protein_coding'},
#  'ENST00000160740': {'contig': '19',
#   'start': 42284020,
#   'end': 42295796,
#   'strand': '+',
#   'transcript_name': 'CIC-201',
#   'gene_id': 'ENSG00000079432',
#   'biotype': 'protein_coding'},
#  'ENST00000160827': {'contig': '16',
#   'start': 29790751,
#   'end': 29805384,
#   'strand': '+',
#   'transcript_name': 'KIF22-201',
#   'gene_id': 'ENSG00000079616',
#   'biotype': 'protein_coding'},
#  'ENST00000161006': {'contig': '16',
#   'start': 2852730,
#   'end': 2858170,
#   'strand': '-',
#   'transcript_name': 'PRSS22-201',
#   'gene_id': 'ENSG00000005001',
#   'biotype': 'protein_coding'},
#  'ENST00000161559': {'contig': '19',
#   'start': 42507306,
#   'end': 42528481,
#   'strand': '-',
#   'transcript_name': 'CEACAM1-201',
#   'gene_id': 'ENSG00000079385',
#   'biotype': 'protein_coding'},
#  'ENST00000161863': {'contig': '5',
#   'start': 113513694,
#   'end': 113595284,
#   'strand': '+',
#   'transcript_name': 'YTHDC2-201',
#   'gene_id': 'ENSG00000047188',
#   'biotype': 'protein_coding'},
#  'ENST00000162044': {'contig': '19',
#   'start': 19119169,
#   'end': 19138478,
#   'strand': '-',
#   'transcript_name': 'TMEM161A-201',
#   'gene_id': 'ENSG00000064545',
#   'biotype': 'protein_coding'},
#  'ENST00000162330': {'contig': '16',
#   'start': 75228181,
#   'end': 75251624,
#   'strand': '-',
#   'transcript_name': 'BCAR1-201',
#   'gene_id': 'ENSG00000050820',
#   'biotype': 'protein_coding'},
#  'ENST00000162391': {'contig': '12',
#   'start': 8032716,
#   'end': 8055517,
#   'strand': '+',
#   'transcript_name': 'FOXJ2-201',
#   'gene_id': 'ENSG00000065970',
#   'biotype': 'protein_coding'},
#  'ENST00000162749': {'contig': '12',
#   'start': 6328771,
#   'end': 6342076,
#   'strand': '-',
#   'transcript_name': 'TNFRSF1A-201',
#   'gene_id': 'ENSG00000067182',
#   'biotype': 'protein_coding'},
#  'ENST00000163416': {'contig': '14',
#   'start': 92794305,
#   'end': 92839947,
#   'strand': '+',
#   'transcript_name': 'GOLGA5-201',
#   'gene_id': 'ENSG00000066455',
#   'biotype': 'protein_coding'},
#  'ENST00000163678': {'contig': '16',
#   'start': 8621691,
#   'end': 8646224,
#   'strand': '+',
#   'transcript_name': 'METTL22-201',
#   'gene_id': 'ENSG00000067365',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000164024': {'contig': '3',
#   'start': 48636463,
#   'end': 48662886,
#   'strand': '-',
#   'transcript_name': 'CELSR3-201',
#   'gene_id': 'ENSG00000008300',
#   'biotype': 'protein_coding'},
#  'ENST00000164133': {'contig': '11',
#   'start': 64924689,
#   'end': 64934475,
#   'strand': '+',
#   'transcript_name': 'PPP2R5B-201',
#   'gene_id': 'ENSG00000068971',
#   'biotype': 'protein_coding'},
#  'ENST00000164139': {'contig': '11',
#   'start': 64746398,
#   'end': 64759974,
#   'strand': '-',
#   'transcript_name': 'PYGM-201',
#   'gene_id': 'ENSG00000068976',
#   'biotype': 'protein_coding'},
#  'ENST00000164227': {'contig': '19',
#   'start': 44748708,
#   'end': 44760044,
#   'strand': '+',
#   'transcript_name': 'BCL3-201',
#   'gene_id': 'ENSG00000069399',
#   'biotype': 'protein_coding'},
#  'ENST00000164247': {'contig': '1',
#   'start': 6034283,
#   'end': 6101179,
#   'strand': '+',
#   'transcript_name': 'KCNAB2-201',
#   'gene_id': 'ENSG00000069424',
#   'biotype': 'protein_coding'},
#  'ENST00000164305': {'contig': '15',
#   'start': 55319222,
#   'end': 55355648,
#   'strand': '+',
#   'transcript_name': 'PIGB-201',
#   'gene_id': 'ENSG00000069943',
#   'biotype': 'protein_coding'},
#  'ENST00000164640': {'contig': 'X',
#   'start': 153802166,
#   'end': 153830490,
#   'strand': '-',
#   'transcript_name': 'PDZD4-201',
#   'gene_id': 'ENSG00000067840',
#   'biotype': 'protein_coding'},
#  'ENST00000165086': {'contig': '16',
#   'start': 21837474,
#   'end': 21843412,
#   'strand': '-',
#   'transcript_name': 'NPIPB4-201',
#   'gene_id': 'ENSG00000185864',
#   'biotype': 'processed_transcript'},
#  'ENST00000165524': {'contig': '2',
#   'start': 237566574,
#   'end': 237567175,
#   'strand': '+',
#   'transcript_name': 'PRLH-201',
#   'gene_id': 'ENSG00000071677',
#   'biotype': 'protein_coding'},
#  'ENST00000165698': {'contig': '2',
#   'start': 86213993,
#   'end': 86337654,
#   'strand': '-',
#   'transcript_name': 'REEP1-201',
#   'gene_id': 'ENSG00000068615',
#   'biotype': 'protein_coding'},
#  'ENST00000166139': {'contig': '19',
#   'start': 676392,
#   'end': 683385,
#   'strand': '+',
#   'transcript_name': 'FSTL3-201',
#   'gene_id': 'ENSG00000070404',
#   'biotype': 'protein_coding'},
#  'ENST00000166244': {'contig': '1',
#   'start': 22563489,
#   'end': 22603595,
#   'strand': '+',
#   'transcript_name': 'EPHA8-201',
#   'gene_id': 'ENSG00000070886',
#   'biotype': 'protein_coding'},
#  'ENST00000166345': {'contig': '5',
#   'start': 892884,
#   'end': 918120,
#   'strand': '+',
#   'transcript_name': 'TRIP13-201',
#   'gene_id': 'ENSG00000071539',
#   'biotype': 'protein_coding'},
#  'ENST00000166534': {'contig': '5',
#   'start': 132192610,
#   'end': 132227857,
#   'strand': '-',
#   'transcript_name': 'P4HA2-201',
#   'gene_id': 'ENSG00000072682',
#   'biotype': 'protein_coding'},
#  'ENST00000167106': {'contig': '14',
#   'start': 76761468,
#   'end': 76783015,
#   'strand': '+',
#   'transcript_name': 'VASH1-201',
#   'gene_id': 'ENSG00000071246',
#   'biotype': 'protein_coding'},
#  'ENST00000167218': {'contig': '6',
#   'start': 170577436,
#   'end': 170584645,
#   'strand': '-',
#   'transcript_name': 'PDCD2-201',
#   'gene_id': 'ENSG00000071994',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000167462': {'contig': '17',
#   'start': 75525726,
#   'end': 75575208,
#   'strand': '+',
#   'transcript_name': 'LLGL2-201',
#   'gene_id': 'ENSG00000073350',
#   'biotype': 'protein_coding'},
#  'ENST00000167586': {'contig': '17',
#   'start': 41582279,
#   'end': 41586895,
#   'strand': '-',
#   'transcript_name': 'KRT14-201',
#   'gene_id': 'ENSG00000186847',
#   'biotype': 'protein_coding'},
#  'ENST00000167588': {'contig': '17',
#   'start': 40875889,
#   'end': 40885242,
#   'strand': '-',
#   'transcript_name': 'KRT20-201',
#   'gene_id': 'ENSG00000171431',
#   'biotype': 'protein_coding'},
#  'ENST00000167825': {'contig': '1',
#   'start': 17626007,
#   'end': 17697868,
#   'strand': '+',
#   'transcript_name': 'ARHGEF10L-201',
#   'gene_id': 'ENSG00000074964',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000168148': {'contig': '2',
#   'start': 234050702,
#   'end': 234077134,
#   'strand': '+',
#   'transcript_name': 'SPP2-201',
#   'gene_id': 'ENSG00000072080',
#   'biotype': 'protein_coding'},
#  'ENST00000168216': {'contig': 'X',
#   'start': 53431261,
#   'end': 53434370,
#   'strand': '-',
#   'transcript_name': 'HSD17B10-201',
#   'gene_id': 'ENSG00000072506',
#   'biotype': 'protein_coding'},
#  'ENST00000168712': {'contig': '11',
#   'start': 69771022,
#   'end': 69775341,
#   'strand': '-',
#   'transcript_name': 'FGF4-201',
#   'gene_id': 'ENSG00000075388',
#   'biotype': 'protein_coding'},
#  'ENST00000168869': {'contig': '16',
#   'start': 268301,
#   'end': 275940,
#   'strand': '-',
#   'transcript_name': 'RGS11-201',
#   'gene_id': 'ENSG00000076344',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000168977': {'contig': '19',
#   'start': 3933069,
#   'end': 3942416,
#   'strand': '+',
#   'transcript_name': 'NMRK2-201',
#   'gene_id': 'ENSG00000077009',
#   'biotype': 'protein_coding'},
#  'ENST00000169293': {'contig': '3',
#   'start': 187246361,
#   'end': 187291957,
#   'strand': '-',
#   'transcript_name': 'MASP1-201',
#   'gene_id': 'ENSG00000127241',
#   'biotype': 'protein_coding'},
#  'ENST00000169298': {'contig': '3',
#   'start': 186930526,
#   'end': 187078553,
#   'strand': '+',
#   'transcript_name': 'ST6GAL1-201',
#   'gene_id': 'ENSG00000073849',
#   'biotype': 'protein_coding'},
#  'ENST00000169551': {'contig': '18',
#   'start': 74148523,
#   'end': 74160531,
#   'strand': '+',
#   'transcript_name': 'TIMM21-201',
#   'gene_id': 'ENSG00000075336',
#   'biotype': 'protein_coding'},
#  'ENST00000170150': {'contig': '20',
#   'start': 33007704,
#   'end': 33023703,
#   'strand': '+',
#   'transcript_name': 'BPIFB2-201',
#   'gene_id': 'ENSG00000078898',
#   'biotype': 'protein_coding'},
#  'ENST00000170168': {'contig': '19',
#   'start': 1815248,
#   'end': 1848483,
#   'strand': '-',
#   'transcript_name': 'REXO1-201',
#   'gene_id': 'ENSG00000079313',
#   'biotype': 'protein_coding'},
#  'ENST00000170447': {'contig': '3',
#   'start': 12557087,
#   'end': 12583713,
#   'strand': '+',
#   'transcript_name': 'MKRN2-201',
#   'gene_id': 'ENSG00000075975',
#   'biotype': 'protein_coding'},
#  'ENST00000170564': {'contig': '19',
#   'start': 33081181,
#   'end': 33130542,
#   'strand': '+',
#   'transcript_name': 'GPATCH1-201',
#   'gene_id': 'ENSG00000076650',
#   'biotype': 'protein_coding'},
#  'ENST00000170630': {'contig': '16',
#   'start': 27341289,
#   'end': 27364777,
#   'strand': '+',
#   'transcript_name': 'IL4R-201',
#   'gene_id': 'ENSG00000077238',
#   'biotype': 'protein_coding'},
#  'ENST00000171111': {'contig': '19',
#   'start': 10486125,
#   'end': 10503356,
#   'strand': '-',
#   'transcript_name': 'KEAP1-201',
#   'gene_id': 'ENSG00000079999',
#   'biotype': 'protein_coding'},
#  'ENST00000171757': {'contig': 'X',
#   'start': 78945391,
#   'end': 78963727,
#   'strand': '+',
#   'transcript_name': 'P2RY10-201',
#   'gene_id': 'ENSG00000078589',
#   'biotype': 'protein_coding'},
#  'ENST00000171887': {'contig': '2',
#   'start': 217799789,
#   'end': 217944128,
#   'strand': '-',
#   'transcript_name': 'TNS1-201',
#   'gene_id': 'ENSG00000079308',
#   'biotype': 'protein_coding'},
#  'ENST00000172229': {'contig': '17',
#   'start': 49495293,
#   'end': 49515008,
#   'strand': '+',
#   'transcript_name': 'NGFR-201',
# ...
#   'biotype': 'protein_coding'},
#  'ENST00000222249': {'contig': '19',
#   'start': 17951293,
#   'end': 18000080,
#   'strand': '+',
#   'transcript_name': 'KCNN1-201',
#   'gene_id': 'ENSG00000105642',
#   'biotype': 'protein_coding'},
#  'ENST00000222250': {'contig': '19',
#   'start': 18008170,
#   'end': 18014102,
#   'strand': '+',
#   'transcript_name': 'ARRDC2-201',
#   'gene_id': 'ENSG00000105643',
#   'biotype': 'protein_coding'},
#  'ENST00000222254': {'contig': '19',
#   'start': 18153163,
#   'end': 18170532,
#   'strand': '+',
#   'transcript_name': 'PIK3R2-201',
#   'gene_id': 'ENSG00000105647',
#   'biotype': 'protein_coding'},
#  'ENST00000222256': {'contig': '19',
#   'start': 18196784,
#   'end': 18204042,
#   'strand': '-',
#   'transcript_name': 'RAB3A-201',
#   'gene_id': 'ENSG00000105649',
#   'biotype': 'protein_coding'},
#  'ENST00000222266': {'contig': '19',
#   'start': 35745619,
#   'end': 35747004,
#   'strand': '+',
#   'transcript_name': 'PSENEN-201',
#   'gene_id': 'ENSG00000205155',
#   'biotype': 'protein_coding'},
#  'ENST00000222271': {'contig': '19',
#   'start': 18782773,
#   'end': 18791305,
#   'strand': '-',
#   'transcript_name': 'COMP-201',
#   'gene_id': 'ENSG00000105664',
#   'biotype': 'protein_coding'},
#  'ENST00000222275': {'contig': '19',
#   'start': 35666517,
#   'end': 35678481,
#   'strand': '+',
#   'transcript_name': 'UPK1A-201',
#   'gene_id': 'ENSG00000105668',
#   'biotype': 'protein_coding'},
#  'ENST00000222284': {'contig': '19',
#   'start': 35545626,
#   'end': 35547526,
#   'strand': '+',
#   'transcript_name': 'TMEM147-201',
#   'gene_id': 'ENSG00000105677',
#   'biotype': 'protein_coding'},
#  'ENST00000222286': {'contig': '19',
#   'start': 35533456,
#   'end': 35545319,
#   'strand': '+',
#   'transcript_name': 'GAPDHS-201',
#   'gene_id': 'ENSG00000105679',
#   'biotype': 'protein_coding'},
#  'ENST00000222304': {'contig': '19',
#   'start': 35282528,
#   'end': 35285143,
#   'strand': '+',
#   'transcript_name': 'HAMP-201',
#   'gene_id': 'ENSG00000105697',
#   'biotype': 'protein_coding'},
#  'ENST00000222305': {'contig': '19',
#   'start': 35268962,
#   'end': 35279821,
#   'strand': '+',
#   'transcript_name': 'USF2-201',
#   'gene_id': 'ENSG00000105698',
#   'biotype': 'protein_coding'},
#  'ENST00000222307': {'contig': '19',
#   'start': 18557870,
#   'end': 18569378,
#   'strand': '+',
#   'transcript_name': 'KXD1-201',
#   'gene_id': 'ENSG00000105700',
#   'biotype': 'protein_coding'},
#  'ENST00000222308': {'contig': '19',
#   'start': 18531762,
#   'end': 18543524,
#   'strand': '-',
#   'transcript_name': 'FKBP8-201',
#   'gene_id': 'ENSG00000105701',
#   'biotype': 'protein_coding'},
#  'ENST00000222329': {'contig': '19',
#   'start': 42247569,
#   'end': 42255128,
#   'strand': '-',
#   'transcript_name': 'ERF-201',
#   'gene_id': 'ENSG00000105722',
#   'biotype': 'protein_coding'},
#  'ENST00000222330': {'contig': '19',
#   'start': 42230190,
#   'end': 42242602,
#   'strand': '-',
#   'transcript_name': 'GSK3A-201',
#   'gene_id': 'ENSG00000105723',
#   'biotype': 'protein_coding'},
#  'ENST00000222339': {'contig': '19',
#   'start': 42068477,
#   'end': 42081410,
#   'strand': '+',
#   'transcript_name': 'ZNF574-201',
#   'gene_id': 'ENSG00000105732',
#   'biotype': 'protein_coding'},
#  'ENST00000222345': {'contig': '19',
#   'start': 37907208,
#   'end': 38208369,
#   'strand': '+',
#   'transcript_name': 'SIPA1L3-201',
#   'gene_id': 'ENSG00000105738',
#   'biotype': 'protein_coding'},
#  'ENST00000222374': {'contig': '19',
#   'start': 43622368,
#   'end': 43639850,
#   'strand': '-',
#   'transcript_name': 'CADM4-201',
#   'gene_id': 'ENSG00000105767',
#   'biotype': 'protein_coding'},
#  'ENST00000222381': {'contig': '7',
#   'start': 95297676,
#   'end': 95324532,
#   'strand': '-',
#   'transcript_name': 'PON1-201',
#   'gene_id': 'ENSG00000005421',
#   'biotype': 'protein_coding'},
#  'ENST00000222382': {'contig': '7',
#   'start': 99828116,
#   'end': 99866001,
#   'strand': '+',
#   'transcript_name': 'CYP3A43-201',
#   'gene_id': 'ENSG00000021461',
#   'biotype': 'protein_coding'},
#  'ENST00000222388': {'contig': '7',
#   'start': 151207837,
#   'end': 151227166,
#   'strand': '-',
#   'transcript_name': 'ABCF2-H2BE1-201',
#   'gene_id': 'ENSG00000285292',
#   'biotype': 'protein_coding'},
#  'ENST00000222390': {'contig': '7',
#   'start': 81699010,
#   'end': 81770047,
#   'strand': '-',
#   'transcript_name': 'HGF-201',
#   'gene_id': 'ENSG00000019991',
#   'biotype': 'protein_coding'},
#  'ENST00000222396': {'contig': '12',
#   'start': 30997038,
#   'end': 31006010,
#   'strand': '-',
#   'transcript_name': '',
#   'gene_id': 'ENSG00000226472',
#   'biotype': 'processed_transcript'},
#  'ENST00000222399': {'contig': '7',
#   'start': 107923799,
#   'end': 108003161,
#   'strand': '-',
#   'transcript_name': 'LAMB1-201',
#   'gene_id': 'ENSG00000091136',
#   'biotype': 'protein_coding'},
#  'ENST00000222402': {'contig': '7',
#   'start': 43926436,
#   'end': 43956136,
#   'strand': '+',
#   'transcript_name': 'UBE2D4-201',
#   'gene_id': 'ENSG00000078967',
#   'biotype': 'protein_coding'},
#  'ENST00000222462': {'contig': '7',
#   'start': 121329000,
#   'end': 121341104,
#   'strand': '+',
#   'transcript_name': 'WNT16-201',
#   'gene_id': 'ENSG00000002745',
#   'biotype': 'protein_coding'},
#  'ENST00000222481': {'contig': '7',
#   'start': 130266863,
#   'end': 130289798,
#   'strand': '+',
#   'transcript_name': 'CPA2-201',
#   'gene_id': 'ENSG00000158516',
#   'biotype': 'protein_coding'},
#  'ENST00000222482': {'contig': '7',
#   'start': 130293161,
#   'end': 130324180,
#   'strand': '+',
#   'transcript_name': 'CPA4-201',
#   'gene_id': 'ENSG00000128510',
#   'biotype': 'protein_coding'},
#  'ENST00000222511': {'contig': '7',
#   'start': 90346716,
#   'end': 90391453,
#   'strand': '+',
#   'transcript_name': 'GTPBP10-201',
#   'gene_id': 'ENSG00000105793',
#   'biotype': 'protein_coding'},
#  'ENST00000222543': {'contig': '7',
#   'start': 93885396,
#   'end': 93890753,
#   'strand': '-',
#   'transcript_name': 'TFPI2-201',
#   'gene_id': 'ENSG00000105825',
#   'biotype': 'protein_coding'},
#  'ENST00000222547': {'contig': '7',
#   'start': 93993245,
#   'end': 94004355,
#   'strand': '-',
#   'transcript_name': 'BET1-201',
#   'gene_id': 'ENSG00000105829',
#   'biotype': 'protein_coding'},
#  'ENST00000222553': {'contig': '7',
#   'start': 106248298,
#   'end': 106284983,
#   'strand': '-',
#   'transcript_name': 'NAMPT-201',
#   'gene_id': 'ENSG00000105835',
#   'biotype': 'protein_coding'},
#  'ENST00000222567': {'contig': '7',
#   'start': 19695461,
#   'end': 19709037,
#   'strand': '-',
#   'transcript_name': 'POLR1F-201',
#   'gene_id': 'ENSG00000105849',
#   'biotype': 'protein_coding'},
#  'ENST00000222572': {'contig': '7',
#   'start': 95404862,
#   'end': 95435028,
#   'strand': '-',
#   'transcript_name': 'PON2-201',
#   'gene_id': 'ENSG00000105854',
#   'biotype': 'protein_coding'},
#  'ENST00000222573': {'contig': '7',
#   'start': 20330900,
#   'end': 20415754,
#   'strand': '+',
#   'transcript_name': 'ITGB8-201',
#   'gene_id': 'ENSG00000105855',
#   'biotype': 'protein_coding'},
#  'ENST00000222574': {'contig': '7',
#   'start': 107169003,
#   'end': 107202522,
#   'strand': '+',
#   'transcript_name': 'HBP1-201',
#   'gene_id': 'ENSG00000105856',
#   'biotype': 'protein_coding'},
#  'ENST00000222584': {'contig': '7',
#   'start': 21428083,
#   'end': 21514822,
#   'strand': '+',
#   'transcript_name': 'SP4-201',
#   'gene_id': 'ENSG00000105866',
#   'biotype': 'protein_coding'},
#  'ENST00000222597': {'contig': '7',
#   'start': 107744142,
#   'end': 107759686,
#   'strand': '+',
#   'transcript_name': 'CBLL1-201',
#   'gene_id': 'ENSG00000105879',
#   'biotype': 'protein_coding'},
#  'ENST00000222644': {'contig': '7',
#   'start': 24573452,
#   'end': 24694193,
#   'strand': '+',
#   'transcript_name': 'PALS2-201',
#   'gene_id': 'ENSG00000105926',
#   'biotype': 'protein_coding'},
#  'ENST00000222673': {'contig': '7',
#   'start': 44606627,
#   'end': 44709066,
#   'strand': '+',
#   'transcript_name': 'OGDH-201',
#   'gene_id': 'ENSG00000105953',
#   'biotype': 'protein_coding'},
#  'ENST00000222674': {'contig': '7',
#   'start': 25224570,
#   'end': 25228486,
#   'strand': '-',
#   'transcript_name': 'NPVF-201',
#   'gene_id': 'ENSG00000105954',
#   'biotype': 'protein_coding'},
#  'ENST00000222690': {'contig': '7',
#   'start': 44826791,
#   'end': 44848077,
#   'strand': '-',
#   'transcript_name': 'H2AZ2-201',
#   'gene_id': 'ENSG00000105968',
#   'biotype': 'protein_coding'},
#  'ENST00000222693': {'contig': '7',
#   'start': 116499738,
#   'end': 116508541,
#   'strand': '+',
#   'transcript_name': 'CAV2-201',
#   'gene_id': 'ENSG00000105971',
#   'biotype': 'protein_coding'},
#  'ENST00000222718': {'contig': '7',
#   'start': 27100354,
#   'end': 27102683,
#   'strand': '-',
#   'transcript_name': 'HOXA2-201',
#   'gene_id': 'ENSG00000105996',
#   'biotype': 'protein_coding'},
#  'ENST00000222725': {'contig': '7',
#   'start': 2519774,
#   'end': 2528429,
#   'strand': '+',
#   'transcript_name': 'LFNG-201',
#   'gene_id': 'ENSG00000106003',
#   'biotype': 'protein_coding'},
#  'ENST00000222726': {'contig': '7',
#   'start': 27141052,
#   'end': 27143681,
#   'strand': '-',
#   'transcript_name': 'HOXA5-201',
#   'gene_id': 'ENSG00000106004',
#   'biotype': 'protein_coding'},
#  'ENST00000222728': {'contig': '7',
#   'start': 27145396,
#   'end': 27147774,
#   'strand': '-',
#   'transcript_name': 'HOXA6-201',
#   'gene_id': 'ENSG00000106006',
#   'biotype': 'protein_coding'},
#  'ENST00000222747': {'contig': '7',
#   'start': 120787320,
#   'end': 120858144,
#   'strand': '-',
#   'transcript_name': 'TSPAN12-201',
#   'gene_id': 'ENSG00000106025',
#   'biotype': 'protein_coding'},
#  'ENST00000222761': {'contig': '7',
#   'start': 27242700,
#   'end': 27246425,
#   'strand': '+',
#   'transcript_name': 'EVX1-201',
#   'gene_id': 'ENSG00000106038',
#   'biotype': 'protein_coding'},
#  'ENST00000222792': {'contig': '7',
#   'start': 29194775,
#   'end': 29514328,
#   'strand': '+',
#   'transcript_name': 'CHN2-201',
#   'gene_id': 'ENSG00000106069',
#   'biotype': 'protein_coding'},
#  'ENST00000222800': {'contig': '7',
#   'start': 73736094,
#   'end': 73738802,
#   'strand': '-',
#   'transcript_name': 'ABHD11-201',
#   'gene_id': 'ENSG00000106077',
#   'biotype': 'protein_coding'},
#  'ENST00000222803': {'contig': '7',
#   'start': 30010587,
#   'end': 30026702,
#   'strand': '-',
#   'transcript_name': 'FKBP14-201',
#   'gene_id': 'ENSG00000106080',
#   'biotype': 'protein_coding'},
#  'ENST00000222812': {'contig': '7',
#   'start': 73699210,
#   'end': 73719669,
#   'strand': '-',
#   'transcript_name': 'STX1A-201',
#   'gene_id': 'ENSG00000106089',
#   'biotype': 'protein_coding'},
#  'ENST00000222823': {'contig': '7',
#   'start': 30424527,
#   'end': 30478784,
#   'strand': '-',
#   'transcript_name': 'NOD1-201',
#   'gene_id': 'ENSG00000106100',
#   'biotype': 'protein_coding'},
#  'ENST00000222902': {'contig': '7',
#   'start': 75810825,
#   'end': 75813806,
#   'strand': '-',
#   'transcript_name': 'CCL24-201',
#   'gene_id': 'ENSG00000106178',
#   'biotype': 'protein_coding'},
#  'ENST00000222969': {'contig': '7',
#   'start': 99408969,
#   'end': 99419616,
#   'strand': '+',
#   'transcript_name': 'BUD31-201',
#   'gene_id': 'ENSG00000106245',
#   'biotype': 'protein_coding'},
#  'ENST00000222982': {'contig': '7',
#   'start': 99648194,
#   'end': 99679996,
#   'strand': '-',
#   'transcript_name': 'CYP3A5-201',
#   'gene_id': 'ENSG00000106258',
#   'biotype': 'protein_coding'},
#  'ENST00000222990': {'contig': '7',
#   'start': 2251770,
#   'end': 2314441,
#   'strand': '-',
#   'transcript_name': 'SNX8-201',
#   'gene_id': 'ENSG00000106266',
#   'biotype': 'protein_coding'},
#  'ENST00000223023': {'contig': '7',
#   'start': 123681943,
#   'end': 123749003,
#   'strand': '-',
#   'transcript_name': 'WASL-201',
#   'gene_id': 'ENSG00000106299',
#   'biotype': 'protein_coding'},
#  'ENST00000223026': {'contig': '7',
#   'start': 123845169,
#   'end': 123877481,
#   'strand': '+',
#   'transcript_name': 'HYAL4-201',
#   'gene_id': 'ENSG00000106302',
#   'biotype': 'protein_coding'},
#  'ENST00000223028': {'contig': '7',
#   'start': 123947700,
#   'end': 123960039,
#   'strand': '+',
#   'transcript_name': 'SPAM1-201',
#   'gene_id': 'ENSG00000106304',
#   'biotype': 'protein_coding'},
#  'ENST00000223029': {'contig': '7',
#   'start': 6009272,
#   'end': 6023834,
#   'strand': '+',
#   'transcript_name': 'AIMP2-201',
#   'gene_id': 'ENSG00000106305',
#   'biotype': 'protein_coding'},
#  'ENST00000223051': {'contig': '7',
#   'start': 100620420,
#   'end': 100641552,
#   'strand': '-',
#   'transcript_name': 'TFR2-201',
#   'gene_id': 'ENSG00000106327',
#   'biotype': 'protein_coding'},
#  'ENST00000223054': {'contig': '7',
#   'start': 100612102,
#   'end': 100615326,
#   'strand': '+',
#   'transcript_name': 'MOSPD3-201',
#   'gene_id': 'ENSG00000106330',
#   'biotype': 'protein_coding'},
#  'ENST00000223061': {'contig': '7',
#   'start': 100602363,
#   'end': 100608175,
#   'strand': '+',
#   'transcript_name': 'PCOLCE-201',
#   'gene_id': 'ENSG00000106333',
#   'biotype': 'protein_coding'},
#  'ENST00000223073': {'contig': '7',
#   'start': 128297685,
#   'end': 128343908,
#   'strand': '-',
#   'transcript_name': 'RBM28-201',
#   'gene_id': 'ENSG00000106344',
#   'biotype': 'protein_coding'},
#  'ENST00000223076': {'contig': '7',
#   'start': 100570131,
#   'end': 100571136,
#   'strand': '+',
#   'transcript_name': 'IRS3P-201',
#   'gene_id': 'ENSG00000184414',
#   'biotype': 'processed_pseudogene'},
#  'ENST00000223084': {'contig': '7',
#   'start': 32487035,
#   'end': 32490863,
#   'strand': '-',
#   'transcript_name': 'LSM5-201',
#   'gene_id': 'ENSG00000106355',
#   'biotype': 'nonsense_mediated_decay'},
#  'ENST00000223095': {'contig': '7',
#   'start': 101127104,
#   'end': 101139247,
#   'strand': '+',
#   'transcript_name': 'SERPINE1-201',
#   'gene_id': 'ENSG00000106366',
#   'biotype': 'protein_coding'},
#  'ENST00000223114': {'contig': '7',
#   'start': 101195007,
#   'end': 101201036,
#   'strand': '-',
#   'transcript_name': 'MOGAT3-201',
#   'gene_id': 'ENSG00000106384',
#   'biotype': 'protein_coding'},
#  'ENST00000223122': {'contig': '7',
#   'start': 7234258,
#   'end': 7244350,
#   'strand': '+',
#   'transcript_name': 'C1GALT1-201',
#   'gene_id': 'ENSG00000106392',
#   'biotype': 'protein_coding'},
#  'ENST00000223127': {'contig': '7',
#   'start': 101205984,
#   'end': 101217581,
#   'strand': '-',
#   'transcript_name': 'PLOD3-201',
#   'gene_id': 'ENSG00000106397',
#   'biotype': 'protein_coding'},
#  'ENST00000223129': {'contig': '7',
#   'start': 7636518,
#   'end': 7718607,
#   'strand': '-',
#   'transcript_name': 'RPA3-201',
#   'gene_id': 'ENSG00000106399',
#   'biotype': 'protein_coding'},
#  'ENST00000223136': {'contig': '7',
#   'start': 101239472,
#   'end': 101245081,
#   'strand': '-',
#   'transcript_name': 'FIS1-201',
#   'gene_id': 'ENSG00000214253',
#   'biotype': 'protein_coding'},
#  'ENST00000223145': {'contig': '7',
#   'start': 7968796,
#   'end': 8089080,
#   'strand': '+',
#   'transcript_name': 'GLCCI1-201',
#   'gene_id': 'ENSG00000106415',
#   'biotype': 'protein_coding'},
#  'ENST00000223167': {'contig': '7',
#   'start': 101613330,
#   'end': 101629296,
#   'strand': '-',
#   'transcript_name': 'MYL10-201',
#   'gene_id': 'ENSG00000106436',
#   'biotype': 'protein_coding'},
#  'ENST00000223190': {'contig': '7',
#   'start': 129611756,
#   'end': 129756015,
#   'strand': '+',
#   'transcript_name': 'NRF1-201',
#   'gene_id': 'ENSG00000106459',
#   'biotype': 'protein_coding'},
#  'ENST00000223208': {'contig': '7',
#   'start': 130393771,
#   'end': 130441016,
#   'strand': '-',
#   'transcript_name': 'CEP41-201',
#   'gene_id': 'ENSG00000106477',
#   'biotype': 'protein_coding'},
#  'ENST00000223210': {'contig': '7',
#   'start': 149838375,
#   'end': 149867479,
#   'strand': '+',
#   'transcript_name': 'ZNF862-201',
#   'gene_id': 'ENSG00000106479',
#   'biotype': 'protein_coding'},
#  'ENST00000223215': {'contig': '7',
#   'start': 130492085,
#   'end': 130506465,
#   'strand': '+',
#   'transcript_name': 'MEST-201',
#   'gene_id': 'ENSG00000106484',
#   'biotype': 'protein_coding'},
#  'ENST00000223271': {'contig': '7',
#   'start': 150338329,
#   'end': 150341629,
#   'strand': '-',
#   'transcript_name': 'RARRES2-201',
#   'gene_id': 'ENSG00000106538',
#   'biotype': 'protein_coding'},
#  'ENST00000223273': {'contig': '7',
#   'start': 39566404,
#   'end': 39572881,
#   'strand': '+',
#   'transcript_name': 'YAE1-201',
#   'gene_id': 'ENSG00000241127',
#   'biotype': 'protein_coding'},
#  'ENST00000223293': {'contig': '7',
#   'start': 150685706,
#   'end': 150693641,
#   'strand': '+',
#   'transcript_name': 'GIMAP2-201',
#   'gene_id': 'ENSG00000106560',
#   'biotype': 'protein_coding'},
#  ...}

# %%
chrom = {}
for d in mapped_transcripts[0]:
    if mapped_transcripts[0][d]['contig'] not in chrom:
        chrom[mapped_transcripts[0][d]['contig']] = 1
    else:
        chrom[mapped_transcripts[0][d]['contig']] += 1

# %%
chrom
# Out:
# {'7': 11738,
#  '12': 13531,
#  '11': 14569,
#  '2': 18395,
#  '6': 11496,
#  '16': 11509,
#  '4': 10095,
#  '3': 15595,
#  '1': 21800,
#  '8': 10095,
#  '19': 14106,
#  '17': 14195,
#  '22': 5270,
#  '5': 11716,
#  '14': 8896,
#  'X': 7861,
#  '10': 8868,
#  '18': 4746,
#  '20': 5918,
#  '13': 4591,
#  '15': 8942,
#  'Y': 841,
#  '9': 8500,
#  '21': 3142,
#  'MT': 37,
#  'GL000194.1': 2,
#  'KI270727.1': 8,
#  'KI270713.1': 4,
#  'GL000216.2': 1,
#  'KI270728.1': 7,
#  'GL000220.1': 4,
#  'KI270442.1': 2,
#  'GL000195.1': 2,
#  'GL000218.1': 1,
#  'KI270711.1': 2,
#  'KI270721.1': 4,
#  'GL000219.1': 1,
#  'KI270750.1': 1,
#  'KI270734.1': 5,
#  'KI270733.1': 4,
#  'GL000213.1': 3,
#  'KI270744.1': 1,
#  'KI270726.1': 2,
#  'GL000009.2': 1,
#  'KI270731.1': 2,
#  'GL000205.2': 1,
#  'GL000225.1': 1}

# %% [markdown]
# ### Get transcript sequences

# %%
transcripts[0]
# Out:
# Transcript(transcript_id='ENST00000000233', transcript_name='ARF5-201', gene_id='ENSG00000004059', biotype='protein_coding', contig='7', start=127588411, end=127591700, strand='+', genome='GRCh38')

# %%
data.transcripts_by_name(transcript_name = 'ARF5-201')
# Out:
# [Transcript(transcript_id='ENST00000000233', transcript_name='ARF5-201', gene_id='ENSG00000004059', biotype='protein_coding', contig='7', start=127588411, end=127591700, strand='+', genome='GRCh38')]

# %%
data.gene_by_id(gene_id = 'ENSG00000004059')
# Out:
# Gene(gene_id='ENSG00000004059', gene_name='ARF5', biotype='protein_coding', contig='7', start=127588386, end=127591700, strand='+', genome='GRCh38')

# %%
len(transcripts)
# Out:
# 246511
